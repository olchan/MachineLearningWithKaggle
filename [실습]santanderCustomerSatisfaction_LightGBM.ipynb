# %% [markdown]
# - label 1 : 불만족
# - label 0: 만족
#
# - [Kaggle data set url](https://www.kaggle.com/competitions/santander-customer-satisfaction/data)

# %%
# !pip uninstall lightgbm
# !pip install lightgbm==3.3.2
# Out:
# Found existing installation: lightgbm 4.1.0
# Uninstalling lightgbm-4.1.0:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/lightgbm-4.1.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/lightgbm/*
# Proceed (Y/n)? y
#   Successfully uninstalled lightgbm-4.1.0
# Collecting lightgbm==3.3.2
#   Downloading lightgbm-3.3.2-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (0.42.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (1.11.4)
# Requirement already satisfied: scikit-learn!=0.22.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm==3.3.2) (1.2.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.2) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn!=0.22.0->lightgbm==3.3.2) (3.2.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import warnings

warnings.filterwarnings('ignore')
cust_df = pd.read_csv('/content/drive/MyDrive/Kaggle - 파이썬 머신러닝 완벽 가이드/kaggleData/santander_customer_satisfaction/train_santander.csv', encoding = 'latin-1')

# %%
# Outlier를 가장 많은 값인 2로 변환
cust_df['var3'].replace(-999999, 2, inplace = True)
cust_df.drop('ID', axis = 1, inplace = True)

# feature set과 label set 분리
X_features = cust_df.iloc[: , : -1]
y_labels = cust_df.iloc[: , -1]
print('feature data shape : {0}'.format(X_features.shape))
# Out:
# feature data shape : (76020, 369)

# %%
from sklearn.model_selection import train_test_split

y_labels = cust_df.iloc[: , -1]
X_train, X_test, y_train, y_test = train_test_split(X_features, y_labels, test_size = 0.2, random_state = 0, stratify = y_labels )

train_cnt = y_train.count()
test_cnt = y_test.count()
print('학습 세트 Shape:{0}, 테스트 세트 Shape:{1}'.format(X_train.shape , X_test.shape))
# Out:
# 학습 세트 Shape:(60816, 369), 테스트 세트 Shape:(15204, 369)

# %%
# data 가 불균형한 분포를 이루고 있기
# target값 분포도가 학습 data와 test data set에 모두 비슷하게 추출되었는 지 확인
print(' 학습 세트 레이블 값 분포 비율')
print(y_train.value_counts()/train_cnt)
print('\n 테스트 세트 레이블 값 분포 비율')
print(y_test.value_counts()/test_cnt)
# Out:
#  학습 세트 레이블 값 분포 비율
# 0    0.960438
# 1    0.039562
# Name: TARGET, dtype: float64
#
#  테스트 세트 레이블 값 분포 비율
# 0    0.960405
# 1    0.039595
# Name: TARGET, dtype: float64

# %%
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, test_size = 0.3, random_state= 0, stratify = y_train)

# %%
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score

lgbm_clf = LGBMClassifier(n_estimators=500)

eval_set=[(X_tr, y_tr), (X_val, y_val)]
lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds=100, eval_metric="auc", eval_set=eval_set)

lgbm_roc_score = roc_auc_score(y_test, lgbm_clf.predict_proba(X_test)[:,1])
print('ROC AUC: {0:.4f}'.format(lgbm_roc_score))
# Out:
# [1]	training's auc: 0.824228	training's binary_logloss: 0.156831	valid_1's auc: 0.816744	valid_1's binary_logloss: 0.158547
# [2]	training's auc: 0.835661	training's binary_logloss: 0.151145	valid_1's auc: 0.827251	valid_1's binary_logloss: 0.153561
# [3]	training's auc: 0.843182	training's binary_logloss: 0.146979	valid_1's auc: 0.828392	valid_1's binary_logloss: 0.150106
# [4]	training's auc: 0.8459	training's binary_logloss: 0.143663	valid_1's auc: 0.828847	valid_1's binary_logloss: 0.147372
# [5]	training's auc: 0.854004	training's binary_logloss: 0.140824	valid_1's auc: 0.832929	valid_1's binary_logloss: 0.145213
# [6]	training's auc: 0.857922	training's binary_logloss: 0.138439	valid_1's auc: 0.835462	valid_1's binary_logloss: 0.143508
# [7]	training's auc: 0.859098	training's binary_logloss: 0.136496	valid_1's auc: 0.835801	valid_1's binary_logloss: 0.142097
# [8]	training's auc: 0.861779	training's binary_logloss: 0.134831	valid_1's auc: 0.838382	valid_1's binary_logloss: 0.140869
# [9]	training's auc: 0.863166	training's binary_logloss: 0.133355	valid_1's auc: 0.838386	valid_1's binary_logloss: 0.139928
# [10]	training's auc: 0.866516	training's binary_logloss: 0.132055	valid_1's auc: 0.838647	valid_1's binary_logloss: 0.139158
# [11]	training's auc: 0.867923	training's binary_logloss: 0.130938	valid_1's auc: 0.839004	valid_1's binary_logloss: 0.138446
# [12]	training's auc: 0.869114	training's binary_logloss: 0.12991	valid_1's auc: 0.838758	valid_1's binary_logloss: 0.137834
# [13]	training's auc: 0.871118	training's binary_logloss: 0.128899	valid_1's auc: 0.839719	valid_1's binary_logloss: 0.137264
# [14]	training's auc: 0.874536	training's binary_logloss: 0.127932	valid_1's auc: 0.840196	valid_1's binary_logloss: 0.136791
# [15]	training's auc: 0.877794	training's binary_logloss: 0.126987	valid_1's auc: 0.839509	valid_1's binary_logloss: 0.136508
# [16]	training's auc: 0.880036	training's binary_logloss: 0.126161	valid_1's auc: 0.840308	valid_1's binary_logloss: 0.136137
# [17]	training's auc: 0.881294	training's binary_logloss: 0.1254	valid_1's auc: 0.84013	valid_1's binary_logloss: 0.135846
# [18]	training's auc: 0.883313	training's binary_logloss: 0.124705	valid_1's auc: 0.839997	valid_1's binary_logloss: 0.135668
# [19]	training's auc: 0.884597	training's binary_logloss: 0.124038	valid_1's auc: 0.84073	valid_1's binary_logloss: 0.135406
# [20]	training's auc: 0.885739	training's binary_logloss: 0.123451	valid_1's auc: 0.840715	valid_1's binary_logloss: 0.135247
# [21]	training's auc: 0.886677	training's binary_logloss: 0.122837	valid_1's auc: 0.841189	valid_1's binary_logloss: 0.135009
# [22]	training's auc: 0.888168	training's binary_logloss: 0.122244	valid_1's auc: 0.84148	valid_1's binary_logloss: 0.134854
# [23]	training's auc: 0.88944	training's binary_logloss: 0.121683	valid_1's auc: 0.841636	valid_1's binary_logloss: 0.134723
# [24]	training's auc: 0.890608	training's binary_logloss: 0.121181	valid_1's auc: 0.841784	valid_1's binary_logloss: 0.134617
# [25]	training's auc: 0.892093	training's binary_logloss: 0.120643	valid_1's auc: 0.841667	valid_1's binary_logloss: 0.134561
# [26]	training's auc: 0.893953	training's binary_logloss: 0.120131	valid_1's auc: 0.841278	valid_1's binary_logloss: 0.134511
# [27]	training's auc: 0.89566	training's binary_logloss: 0.119595	valid_1's auc: 0.842158	valid_1's binary_logloss: 0.134312
# [28]	training's auc: 0.896562	training's binary_logloss: 0.119104	valid_1's auc: 0.842229	valid_1's binary_logloss: 0.134255
# [29]	training's auc: 0.898065	training's binary_logloss: 0.118608	valid_1's auc: 0.842142	valid_1's binary_logloss: 0.134194
# [30]	training's auc: 0.899197	training's binary_logloss: 0.118112	valid_1's auc: 0.841959	valid_1's binary_logloss: 0.134193
# [31]	training's auc: 0.899846	training's binary_logloss: 0.117737	valid_1's auc: 0.841909	valid_1's binary_logloss: 0.134159
# [32]	training's auc: 0.900984	training's binary_logloss: 0.117328	valid_1's auc: 0.84175	valid_1's binary_logloss: 0.134155
# [33]	training's auc: 0.902249	training's binary_logloss: 0.116893	valid_1's auc: 0.841684	valid_1's binary_logloss: 0.134144
# [34]	training's auc: 0.903187	training's binary_logloss: 0.116501	valid_1's auc: 0.841409	valid_1's binary_logloss: 0.134137
# [35]	training's auc: 0.905203	training's binary_logloss: 0.115984	valid_1's auc: 0.84148	valid_1's binary_logloss: 0.134126
# [36]	training's auc: 0.90623	training's binary_logloss: 0.115643	valid_1's auc: 0.841548	valid_1's binary_logloss: 0.134126
# [37]	training's auc: 0.907836	training's binary_logloss: 0.115224	valid_1's auc: 0.842224	valid_1's binary_logloss: 0.134014
# [38]	training's auc: 0.908792	training's binary_logloss: 0.114799	valid_1's auc: 0.842333	valid_1's binary_logloss: 0.134024
# [39]	training's auc: 0.909162	training's binary_logloss: 0.114523	valid_1's auc: 0.842239	valid_1's binary_logloss: 0.134001
# [40]	training's auc: 0.910226	training's binary_logloss: 0.114066	valid_1's auc: 0.842366	valid_1's binary_logloss: 0.133951
# [41]	training's auc: 0.911376	training's binary_logloss: 0.113638	valid_1's auc: 0.842741	valid_1's binary_logloss: 0.133869
# [42]	training's auc: 0.912197	training's binary_logloss: 0.113352	valid_1's auc: 0.842708	valid_1's binary_logloss: 0.133883
# [43]	training's auc: 0.912881	training's binary_logloss: 0.113035	valid_1's auc: 0.842508	valid_1's binary_logloss: 0.133925
# [44]	training's auc: 0.91341	training's binary_logloss: 0.11272	valid_1's auc: 0.842139	valid_1's binary_logloss: 0.133972
# [45]	training's auc: 0.913887	training's binary_logloss: 0.112433	valid_1's auc: 0.842357	valid_1's binary_logloss: 0.133938
# [46]	training's auc: 0.9146	training's binary_logloss: 0.112118	valid_1's auc: 0.842316	valid_1's binary_logloss: 0.133968
# [47]	training's auc: 0.915312	training's binary_logloss: 0.1118	valid_1's auc: 0.841969	valid_1's binary_logloss: 0.134037
# [48]	training's auc: 0.915834	training's binary_logloss: 0.111545	valid_1's auc: 0.84218	valid_1's binary_logloss: 0.133987
# [49]	training's auc: 0.916336	training's binary_logloss: 0.111259	valid_1's auc: 0.842017	valid_1's binary_logloss: 0.13403
# [50]	training's auc: 0.917036	training's binary_logloss: 0.110943	valid_1's auc: 0.841774	valid_1's binary_logloss: 0.134017
# [51]	training's auc: 0.917812	training's binary_logloss: 0.110613	valid_1's auc: 0.841642	valid_1's binary_logloss: 0.134038
# [52]	training's auc: 0.918334	training's binary_logloss: 0.110255	valid_1's auc: 0.841651	valid_1's binary_logloss: 0.134006
# [53]	training's auc: 0.918713	training's binary_logloss: 0.11004	valid_1's auc: 0.841604	valid_1's binary_logloss: 0.13404
# [54]	training's auc: 0.919375	training's binary_logloss: 0.109783	valid_1's auc: 0.841304	valid_1's binary_logloss: 0.134084
# [55]	training's auc: 0.919702	training's binary_logloss: 0.109545	valid_1's auc: 0.841044	valid_1's binary_logloss: 0.134085
# [56]	training's auc: 0.920181	training's binary_logloss: 0.109263	valid_1's auc: 0.841075	valid_1's binary_logloss: 0.134101
# [57]	training's auc: 0.920682	training's binary_logloss: 0.108963	valid_1's auc: 0.841394	valid_1's binary_logloss: 0.134047
# [58]	training's auc: 0.920966	training's binary_logloss: 0.108762	valid_1's auc: 0.841588	valid_1's binary_logloss: 0.133999
# [59]	training's auc: 0.9212	training's binary_logloss: 0.108567	valid_1's auc: 0.841578	valid_1's binary_logloss: 0.13398
# [60]	training's auc: 0.92166	training's binary_logloss: 0.108344	valid_1's auc: 0.841412	valid_1's binary_logloss: 0.133994
# [61]	training's auc: 0.922112	training's binary_logloss: 0.108136	valid_1's auc: 0.84155	valid_1's binary_logloss: 0.133956
# [62]	training's auc: 0.922524	training's binary_logloss: 0.107901	valid_1's auc: 0.841496	valid_1's binary_logloss: 0.133944
# [63]	training's auc: 0.923071	training's binary_logloss: 0.107599	valid_1's auc: 0.84152	valid_1's binary_logloss: 0.133942
# [64]	training's auc: 0.923497	training's binary_logloss: 0.10741	valid_1's auc: 0.841395	valid_1's binary_logloss: 0.133944
# [65]	training's auc: 0.923736	training's binary_logloss: 0.107233	valid_1's auc: 0.841319	valid_1's binary_logloss: 0.133984
# [66]	training's auc: 0.924049	training's binary_logloss: 0.107025	valid_1's auc: 0.841262	valid_1's binary_logloss: 0.133979
# [67]	training's auc: 0.924469	training's binary_logloss: 0.106769	valid_1's auc: 0.841309	valid_1's binary_logloss: 0.133975
# [68]	training's auc: 0.924943	training's binary_logloss: 0.106531	valid_1's auc: 0.841116	valid_1's binary_logloss: 0.134036
# [69]	training's auc: 0.925453	training's binary_logloss: 0.106262	valid_1's auc: 0.841361	valid_1's binary_logloss: 0.134016
# [70]	training's auc: 0.925726	training's binary_logloss: 0.106079	valid_1's auc: 0.841262	valid_1's binary_logloss: 0.134012
# [71]	training's auc: 0.926084	training's binary_logloss: 0.105849	valid_1's auc: 0.841368	valid_1's binary_logloss: 0.13402
# [72]	training's auc: 0.926793	training's binary_logloss: 0.105595	valid_1's auc: 0.841338	valid_1's binary_logloss: 0.134034
# [73]	training's auc: 0.927209	training's binary_logloss: 0.105373	valid_1's auc: 0.840988	valid_1's binary_logloss: 0.134111
# [74]	training's auc: 0.927882	training's binary_logloss: 0.105101	valid_1's auc: 0.840823	valid_1's binary_logloss: 0.134171
# [75]	training's auc: 0.928263	training's binary_logloss: 0.104859	valid_1's auc: 0.840734	valid_1's binary_logloss: 0.134204
# [76]	training's auc: 0.928499	training's binary_logloss: 0.104676	valid_1's auc: 0.840392	valid_1's binary_logloss: 0.13428
# [77]	training's auc: 0.92875	training's binary_logloss: 0.104528	valid_1's auc: 0.840364	valid_1's binary_logloss: 0.134292
# [78]	training's auc: 0.929403	training's binary_logloss: 0.104219	valid_1's auc: 0.840475	valid_1's binary_logloss: 0.134251
# [79]	training's auc: 0.929865	training's binary_logloss: 0.10393	valid_1's auc: 0.840412	valid_1's binary_logloss: 0.134256
# [80]	training's auc: 0.930979	training's binary_logloss: 0.103531	valid_1's auc: 0.840114	valid_1's binary_logloss: 0.134307
# [81]	training's auc: 0.931129	training's binary_logloss: 0.103399	valid_1's auc: 0.840044	valid_1's binary_logloss: 0.134326
# [82]	training's auc: 0.93163	training's binary_logloss: 0.103156	valid_1's auc: 0.840447	valid_1's binary_logloss: 0.134224
# [83]	training's auc: 0.931913	training's binary_logloss: 0.102991	valid_1's auc: 0.840195	valid_1's binary_logloss: 0.134276
# [84]	training's auc: 0.932091	training's binary_logloss: 0.102843	valid_1's auc: 0.840105	valid_1's binary_logloss: 0.134296
# [85]	training's auc: 0.93268	training's binary_logloss: 0.102581	valid_1's auc: 0.840323	valid_1's binary_logloss: 0.134241
# [86]	training's auc: 0.932932	training's binary_logloss: 0.102409	valid_1's auc: 0.840388	valid_1's binary_logloss: 0.134248
# [87]	training's auc: 0.933095	training's binary_logloss: 0.102257	valid_1's auc: 0.84006	valid_1's binary_logloss: 0.134316
# [88]	training's auc: 0.933351	training's binary_logloss: 0.102087	valid_1's auc: 0.839823	valid_1's binary_logloss: 0.134365
# [89]	training's auc: 0.93355	training's binary_logloss: 0.101924	valid_1's auc: 0.839417	valid_1's binary_logloss: 0.134431
# [90]	training's auc: 0.933977	training's binary_logloss: 0.101757	valid_1's auc: 0.839078	valid_1's binary_logloss: 0.134518
# [91]	training's auc: 0.934907	training's binary_logloss: 0.101488	valid_1's auc: 0.839357	valid_1's binary_logloss: 0.134465
# [92]	training's auc: 0.93517	training's binary_logloss: 0.101319	valid_1's auc: 0.839435	valid_1's binary_logloss: 0.134458
# [93]	training's auc: 0.935317	training's binary_logloss: 0.101171	valid_1's auc: 0.839523	valid_1's binary_logloss: 0.134461
# [94]	training's auc: 0.935602	training's binary_logloss: 0.100982	valid_1's auc: 0.839406	valid_1's binary_logloss: 0.134499
# [95]	training's auc: 0.935959	training's binary_logloss: 0.100794	valid_1's auc: 0.839322	valid_1's binary_logloss: 0.134526
# [96]	training's auc: 0.936218	training's binary_logloss: 0.100606	valid_1's auc: 0.839032	valid_1's binary_logloss: 0.134599
# [97]	training's auc: 0.936558	training's binary_logloss: 0.100391	valid_1's auc: 0.838938	valid_1's binary_logloss: 0.134628
# [98]	training's auc: 0.936631	training's binary_logloss: 0.100312	valid_1's auc: 0.838806	valid_1's binary_logloss: 0.134657
# [99]	training's auc: 0.936816	training's binary_logloss: 0.100148	valid_1's auc: 0.838463	valid_1's binary_logloss: 0.134727
# [100]	training's auc: 0.937124	training's binary_logloss: 0.10001	valid_1's auc: 0.838214	valid_1's binary_logloss: 0.13481
# [101]	training's auc: 0.937364	training's binary_logloss: 0.0998408	valid_1's auc: 0.838028	valid_1's binary_logloss: 0.13485
# [102]	training's auc: 0.937503	training's binary_logloss: 0.0997225	valid_1's auc: 0.837715	valid_1's binary_logloss: 0.134919
# [103]	training's auc: 0.938231	training's binary_logloss: 0.0994409	valid_1's auc: 0.837591	valid_1's binary_logloss: 0.134963
# [104]	training's auc: 0.938496	training's binary_logloss: 0.0992639	valid_1's auc: 0.837582	valid_1's binary_logloss: 0.135
# [105]	training's auc: 0.938577	training's binary_logloss: 0.0991695	valid_1's auc: 0.837262	valid_1's binary_logloss: 0.135079
# [106]	training's auc: 0.939355	training's binary_logloss: 0.0989316	valid_1's auc: 0.837308	valid_1's binary_logloss: 0.135081
# [107]	training's auc: 0.939973	training's binary_logloss: 0.0986835	valid_1's auc: 0.837121	valid_1's binary_logloss: 0.135131
# [108]	training's auc: 0.940179	training's binary_logloss: 0.0985144	valid_1's auc: 0.837014	valid_1's binary_logloss: 0.13518
# [109]	training's auc: 0.940586	training's binary_logloss: 0.0983064	valid_1's auc: 0.83719	valid_1's binary_logloss: 0.135166
# [110]	training's auc: 0.940722	training's binary_logloss: 0.0981849	valid_1's auc: 0.836701	valid_1's binary_logloss: 0.135271
# [111]	training's auc: 0.94094	training's binary_logloss: 0.0980146	valid_1's auc: 0.836668	valid_1's binary_logloss: 0.135298
# [112]	training's auc: 0.941439	training's binary_logloss: 0.0977937	valid_1's auc: 0.836891	valid_1's binary_logloss: 0.135265
# [113]	training's auc: 0.94178	training's binary_logloss: 0.097612	valid_1's auc: 0.836617	valid_1's binary_logloss: 0.135337
# [114]	training's auc: 0.941944	training's binary_logloss: 0.0974716	valid_1's auc: 0.836604	valid_1's binary_logloss: 0.135356
# [115]	training's auc: 0.942825	training's binary_logloss: 0.0972124	valid_1's auc: 0.836927	valid_1's binary_logloss: 0.135333
# [116]	training's auc: 0.943462	training's binary_logloss: 0.0969963	valid_1's auc: 0.836761	valid_1's binary_logloss: 0.135371
# [117]	training's auc: 0.944061	training's binary_logloss: 0.0967633	valid_1's auc: 0.836905	valid_1's binary_logloss: 0.135389
# [118]	training's auc: 0.944322	training's binary_logloss: 0.0966203	valid_1's auc: 0.836936	valid_1's binary_logloss: 0.135429
# [119]	training's auc: 0.944644	training's binary_logloss: 0.0964357	valid_1's auc: 0.836935	valid_1's binary_logloss: 0.135481
# [120]	training's auc: 0.945226	training's binary_logloss: 0.0962431	valid_1's auc: 0.836843	valid_1's binary_logloss: 0.135511
# [121]	training's auc: 0.945344	training's binary_logloss: 0.0961334	valid_1's auc: 0.836482	valid_1's binary_logloss: 0.135597
# [122]	training's auc: 0.945665	training's binary_logloss: 0.0960076	valid_1's auc: 0.836416	valid_1's binary_logloss: 0.135644
# [123]	training's auc: 0.945807	training's binary_logloss: 0.0959004	valid_1's auc: 0.83651	valid_1's binary_logloss: 0.135673
# [124]	training's auc: 0.945901	training's binary_logloss: 0.0958057	valid_1's auc: 0.836293	valid_1's binary_logloss: 0.135757
# [125]	training's auc: 0.94616	training's binary_logloss: 0.0956381	valid_1's auc: 0.836301	valid_1's binary_logloss: 0.135779
# [126]	training's auc: 0.946338	training's binary_logloss: 0.0955274	valid_1's auc: 0.836126	valid_1's binary_logloss: 0.135843
# [127]	training's auc: 0.946632	training's binary_logloss: 0.0953108	valid_1's auc: 0.836228	valid_1's binary_logloss: 0.135847
# [128]	training's auc: 0.946802	training's binary_logloss: 0.0951863	valid_1's auc: 0.836324	valid_1's binary_logloss: 0.135823
# [129]	training's auc: 0.946929	training's binary_logloss: 0.0950756	valid_1's auc: 0.836302	valid_1's binary_logloss: 0.135855
# [130]	training's auc: 0.947021	training's binary_logloss: 0.0949728	valid_1's auc: 0.83593	valid_1's binary_logloss: 0.13593
# [131]	training's auc: 0.947207	training's binary_logloss: 0.0948594	valid_1's auc: 0.836118	valid_1's binary_logloss: 0.135928
# [132]	training's auc: 0.947708	training's binary_logloss: 0.0946234	valid_1's auc: 0.836092	valid_1's binary_logloss: 0.13598
# [133]	training's auc: 0.947779	training's binary_logloss: 0.0945227	valid_1's auc: 0.835735	valid_1's binary_logloss: 0.136068
# [134]	training's auc: 0.94792	training's binary_logloss: 0.0943859	valid_1's auc: 0.835658	valid_1's binary_logloss: 0.1361
# [135]	training's auc: 0.948026	training's binary_logloss: 0.0942642	valid_1's auc: 0.83574	valid_1's binary_logloss: 0.136096
# [136]	training's auc: 0.948076	training's binary_logloss: 0.0941962	valid_1's auc: 0.8357	valid_1's binary_logloss: 0.136112
# [137]	training's auc: 0.948146	training's binary_logloss: 0.0941105	valid_1's auc: 0.835457	valid_1's binary_logloss: 0.136154
# [138]	training's auc: 0.94852	training's binary_logloss: 0.0939292	valid_1's auc: 0.835307	valid_1's binary_logloss: 0.136192
# [139]	training's auc: 0.948622	training's binary_logloss: 0.0938259	valid_1's auc: 0.835327	valid_1's binary_logloss: 0.136203
# [140]	training's auc: 0.948728	training's binary_logloss: 0.0937181	valid_1's auc: 0.835033	valid_1's binary_logloss: 0.136284
# [141]	training's auc: 0.948793	training's binary_logloss: 0.09363	valid_1's auc: 0.834781	valid_1's binary_logloss: 0.136354
# ROC AUC: 0.8213

# %%
# 검색 공간 설정
from hyperopt import hp
lgbm_search_space = {'num_leaves': hp.quniform('num_leaves', 32, 64, 1),
                     'max_depth': hp.quniform('max_depth', 100, 160, 1),
                     'min_child_samples': hp.quniform('min_child_samples', 60, 100, 1),
                     'subsample': hp.uniform('subsample', 0.7, 1),
                     'learning_rate': hp.uniform('learning_rate', 0.01, 0.2)
                    }

# %%
# 목적 함수 정의
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

def objective_func(search_space):
    lgbm_clf =  LGBMClassifier(n_estimators=100, num_leaves=int(search_space['num_leaves']),
                               max_depth=int(search_space['max_depth']),
                               min_child_samples=int(search_space['min_child_samples']),
                               subsample=search_space['subsample'],
                               learning_rate=search_space['learning_rate'])
    # 3개 k-fold 방식으로 평가된 roc_auc 지표를 담는 list
    roc_auc_list = []

    # 3개 k-fold방식 적용
    kf = KFold(n_splits=3)
    # X_train을 다시 학습과 검증용 데이터로 분리
    for tr_index, val_index in kf.split(X_train):
        # kf.split(X_train)으로 추출된 학습과 검증 index값으로 학습과 검증 데이터 세트 분리
        X_tr, y_tr = X_train.iloc[tr_index], y_train.iloc[tr_index]
        X_val, y_val = X_train.iloc[val_index], y_train.iloc[val_index]

        # early stopping은 30회로 설정하고 추출된 학습과 검증 데이터로 XGBClassifier 학습 수행.
        lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds=30, eval_metric="auc",
           eval_set=[(X_tr, y_tr), (X_val, y_val)])

        # 1로 예측한 확률값 추출후 roc auc 계산하고 평균 roc auc 계산을 위해 list에 결과값 담음.
        score = roc_auc_score(y_val, lgbm_clf.predict_proba(X_val)[:, 1])
        roc_auc_list.append(score)

    # 3개 k-fold로 계산된 roc_auc값의 평균값을 반환하되,
    # HyperOpt는 목적함수의 최소값을 위한 입력값을 찾으므로 -1을 곱한 뒤 반환.
    return -1*np.mean(roc_auc_list)

# %%
from hyperopt import fmin, tpe, Trials

trials = Trials()

best = fmin(fn = objective_func, space = lgbm_search_space, algo = tpe.suggest, max_evals = 10,
            trials = trials, rstate = np.random.default_rng(seed = 30))
print('best : ', best)
# Out:
# [1]	training's auc: 0.829117	training's binary_logloss: 0.166068	valid_1's auc: 0.813958	valid_1's binary_logloss: 0.16088
# [2]	training's auc: 0.831752	training's binary_logloss: 0.163964	valid_1's auc: 0.814755	valid_1's binary_logloss: 0.159158
# [3]	training's auc: 0.834075	training's binary_logloss: 0.162086	valid_1's auc: 0.817047	valid_1's binary_logloss: 0.157587
# [4]	training's auc: 0.836349	training's binary_logloss: 0.160373	valid_1's auc: 0.819498	valid_1's binary_logloss: 0.156133
# [5]	training's auc: 0.837338	training's binary_logloss: 0.158759	valid_1's auc: 0.819873	valid_1's binary_logloss: 0.154853
# [6]	training's auc: 0.839626	training's binary_logloss: 0.157287	valid_1's auc: 0.821021	valid_1's binary_logloss: 0.153685
# [7]	training's auc: 0.840867	training's binary_logloss: 0.155944	valid_1's auc: 0.82119	valid_1's binary_logloss: 0.152589
# [8]	training's auc: 0.842884	training's binary_logloss: 0.154696	valid_1's auc: 0.822871	valid_1's binary_logloss: 0.15158
# [9]	training's auc: 0.844108	training's binary_logloss: 0.153518	valid_1's auc: 0.823349	valid_1's binary_logloss: 0.150622
# [10]	training's auc: 0.845465	training's binary_logloss: 0.152432	valid_1's auc: 0.823672	valid_1's binary_logloss: 0.149735
# [11]	training's auc: 0.846461	training's binary_logloss: 0.151404	valid_1's auc: 0.823961	valid_1's binary_logloss: 0.148907
# [12]	training's auc: 0.846916	training's binary_logloss: 0.150444	valid_1's auc: 0.823916	valid_1's binary_logloss: 0.148132
# [13]	training's auc: 0.847286	training's binary_logloss: 0.149537	valid_1's auc: 0.824194	valid_1's binary_logloss: 0.1474
# [14]	training's auc: 0.848037	training's binary_logloss: 0.148672	valid_1's auc: 0.824052	valid_1's binary_logloss: 0.146742
# [15]	training's auc: 0.849133	training's binary_logloss: 0.147852	valid_1's auc: 0.824382	valid_1's binary_logloss: 0.146101
# [16]	training's auc: 0.850482	training's binary_logloss: 0.147074	valid_1's auc: 0.82554	valid_1's binary_logloss: 0.145479
# [17]	training's auc: 0.851208	training's binary_logloss: 0.146334	valid_1's auc: 0.825728	valid_1's binary_logloss: 0.144891
# [18]	training's auc: 0.851926	training's binary_logloss: 0.145593	valid_1's auc: 0.825872	valid_1's binary_logloss: 0.144358
# [19]	training's auc: 0.852712	training's binary_logloss: 0.144884	valid_1's auc: 0.82669	valid_1's binary_logloss: 0.143823
# [20]	training's auc: 0.855828	training's binary_logloss: 0.144215	valid_1's auc: 0.829811	valid_1's binary_logloss: 0.143304
# [21]	training's auc: 0.85661	training's binary_logloss: 0.143584	valid_1's auc: 0.829839	valid_1's binary_logloss: 0.142847
# [22]	training's auc: 0.856805	training's binary_logloss: 0.142988	valid_1's auc: 0.82987	valid_1's binary_logloss: 0.142383
# [23]	training's auc: 0.856972	training's binary_logloss: 0.142403	valid_1's auc: 0.830069	valid_1's binary_logloss: 0.141969
# [24]	training's auc: 0.857457	training's binary_logloss: 0.141836	valid_1's auc: 0.830676	valid_1's binary_logloss: 0.141554
# [25]	training's auc: 0.857663	training's binary_logloss: 0.141301	valid_1's auc: 0.830889	valid_1's binary_logloss: 0.141179
# [26]	training's auc: 0.858239	training's binary_logloss: 0.140778	valid_1's auc: 0.831067	valid_1's binary_logloss: 0.140793
# [27]	training's auc: 0.858456	training's binary_logloss: 0.14029	valid_1's auc: 0.831033	valid_1's binary_logloss: 0.140456
# [28]	training's auc: 0.858803	training's binary_logloss: 0.139798	valid_1's auc: 0.831292	valid_1's binary_logloss: 0.140127
# [29]	training's auc: 0.85931	training's binary_logloss: 0.139328	valid_1's auc: 0.831322	valid_1's binary_logloss: 0.13981
# [30]	training's auc: 0.859983	training's binary_logloss: 0.13887	valid_1's auc: 0.831218	valid_1's binary_logloss: 0.139529
# [31]	training's auc: 0.860505	training's binary_logloss: 0.138424	valid_1's auc: 0.83116	valid_1's binary_logloss: 0.139258
# [32]	training's auc: 0.861174	training's binary_logloss: 0.138005	valid_1's auc: 0.831735	valid_1's binary_logloss: 0.138989
# [33]	training's auc: 0.861656	training's binary_logloss: 0.137602	valid_1's auc: 0.831559	valid_1's binary_logloss: 0.138741
# [34]	training's auc: 0.862095	training's binary_logloss: 0.137214	valid_1's auc: 0.832338	valid_1's binary_logloss: 0.138457
# [35]	training's auc: 0.862357	training's binary_logloss: 0.13683	valid_1's auc: 0.832593	valid_1's binary_logloss: 0.138211
# [36]	training's auc: 0.862666	training's binary_logloss: 0.136472	valid_1's auc: 0.832743	valid_1's binary_logloss: 0.137947
# [37]	training's auc: 0.862966	training's binary_logloss: 0.136119	valid_1's auc: 0.832721	valid_1's binary_logloss: 0.137723
# [38]	training's auc: 0.863297	training's binary_logloss: 0.135781	valid_1's auc: 0.832907	valid_1's binary_logloss: 0.137504
# [39]	training's auc: 0.864627	training's binary_logloss: 0.13546	valid_1's auc: 0.833937	valid_1's binary_logloss: 0.137278
# [40]	training's auc: 0.864764	training's binary_logloss: 0.135138	valid_1's auc: 0.834328	valid_1's binary_logloss: 0.137064
# [41]	training's auc: 0.865142	training's binary_logloss: 0.134821	valid_1's auc: 0.834506	valid_1's binary_logloss: 0.136856
# [42]	training's auc: 0.86557	training's binary_logloss: 0.134513	valid_1's auc: 0.83464	valid_1's binary_logloss: 0.136672
# [43]	training's auc: 0.865762	training's binary_logloss: 0.134223	valid_1's auc: 0.834956	valid_1's binary_logloss: 0.136492
# [44]	training's auc: 0.866413	training's binary_logloss: 0.133944	valid_1's auc: 0.835143	valid_1's binary_logloss: 0.136315
# [45]	training's auc: 0.866837	training's binary_logloss: 0.133676	valid_1's auc: 0.835559	valid_1's binary_logloss: 0.136135
# [46]	training's auc: 0.867159	training's binary_logloss: 0.133399	valid_1's auc: 0.835697	valid_1's binary_logloss: 0.135984
# [47]	training's auc: 0.867821	training's binary_logloss: 0.133127	valid_1's auc: 0.83654	valid_1's binary_logloss: 0.135826
# [48]	training's auc: 0.868098	training's binary_logloss: 0.132857	valid_1's auc: 0.83664	valid_1's binary_logloss: 0.135668
# [49]	training's auc: 0.868582	training's binary_logloss: 0.132589	valid_1's auc: 0.836803	valid_1's binary_logloss: 0.13551
# [50]	training's auc: 0.868881	training's binary_logloss: 0.132337	valid_1's auc: 0.836765	valid_1's binary_logloss: 0.135354
# [51]	training's auc: 0.869292	training's binary_logloss: 0.132089	valid_1's auc: 0.837213	valid_1's binary_logloss: 0.135205
# [52]	training's auc: 0.869657	training's binary_logloss: 0.131848	valid_1's auc: 0.837419	valid_1's binary_logloss: 0.135065
# [53]	training's auc: 0.870153	training's binary_logloss: 0.131595	valid_1's auc: 0.837622	valid_1's binary_logloss: 0.134924
# [54]	training's auc: 0.870658	training's binary_logloss: 0.13136	valid_1's auc: 0.83758	valid_1's binary_logloss: 0.134776
# [55]	training's auc: 0.871026	training's binary_logloss: 0.131128	valid_1's auc: 0.837684	valid_1's binary_logloss: 0.134635
# [56]	training's auc: 0.871054	training's binary_logloss: 0.13092	valid_1's auc: 0.837919	valid_1's binary_logloss: 0.134525
# [57]	training's auc: 0.871497	training's binary_logloss: 0.130683	valid_1's auc: 0.838153	valid_1's binary_logloss: 0.134418
# [58]	training's auc: 0.871843	training's binary_logloss: 0.130476	valid_1's auc: 0.838224	valid_1's binary_logloss: 0.134308
# [59]	training's auc: 0.872123	training's binary_logloss: 0.130259	valid_1's auc: 0.838374	valid_1's binary_logloss: 0.134203
# [60]	training's auc: 0.872679	training's binary_logloss: 0.130037	valid_1's auc: 0.838425	valid_1's binary_logloss: 0.134089
# [61]	training's auc: 0.873118	training's binary_logloss: 0.129828	valid_1's auc: 0.838433	valid_1's binary_logloss: 0.133998
# [62]	training's auc: 0.873617	training's binary_logloss: 0.129628	valid_1's auc: 0.838502	valid_1's binary_logloss: 0.133909
# [63]	training's auc: 0.87392	training's binary_logloss: 0.129434	valid_1's auc: 0.83864	valid_1's binary_logloss: 0.133814
# [64]	training's auc: 0.874497	training's binary_logloss: 0.129239	valid_1's auc: 0.839075	valid_1's binary_logloss: 0.133715
# [65]	training's auc: 0.874792	training's binary_logloss: 0.129067	valid_1's auc: 0.839128	valid_1's binary_logloss: 0.133629
# [66]	training's auc: 0.875129	training's binary_logloss: 0.128889	valid_1's auc: 0.839383	valid_1's binary_logloss: 0.133544
# [67]	training's auc: 0.875547	training's binary_logloss: 0.128699	valid_1's auc: 0.839588	valid_1's binary_logloss: 0.133468
# [68]	training's auc: 0.875795	training's binary_logloss: 0.12852	valid_1's auc: 0.839569	valid_1's binary_logloss: 0.133403
# [69]	training's auc: 0.876086	training's binary_logloss: 0.128354	valid_1's auc: 0.839637	valid_1's binary_logloss: 0.133337
# [70]	training's auc: 0.876441	training's binary_logloss: 0.128178	valid_1's auc: 0.839609	valid_1's binary_logloss: 0.133267
# [71]	training's auc: 0.876688	training's binary_logloss: 0.128006	valid_1's auc: 0.83967	valid_1's binary_logloss: 0.133208
# [72]	training's auc: 0.877033	training's binary_logloss: 0.12784	valid_1's auc: 0.839575	valid_1's binary_logloss: 0.133153
# [73]	training's auc: 0.877402	training's binary_logloss: 0.127686	valid_1's auc: 0.839565	valid_1's binary_logloss: 0.13308
# [74]	training's auc: 0.877757	training's binary_logloss: 0.127524	valid_1's auc: 0.83948	valid_1's binary_logloss: 0.133028
# [75]	training's auc: 0.878243	training's binary_logloss: 0.127373	valid_1's auc: 0.839726	valid_1's binary_logloss: 0.132959
# [76]	training's auc: 0.878632	training's binary_logloss: 0.127214	valid_1's auc: 0.839743	valid_1's binary_logloss: 0.132896
# [77]	training's auc: 0.878883	training's binary_logloss: 0.127065	valid_1's auc: 0.839948	valid_1's binary_logloss: 0.132831
# [78]	training's auc: 0.879101	training's binary_logloss: 0.126914	valid_1's auc: 0.839987	valid_1's binary_logloss: 0.132779
# [79]	training's auc: 0.879408	training's binary_logloss: 0.126764	valid_1's auc: 0.839907	valid_1's binary_logloss: 0.132741
# [80]	training's auc: 0.879791	training's binary_logloss: 0.126629	valid_1's auc: 0.840095	valid_1's binary_logloss: 0.13267
# [81]	training's auc: 0.880048	training's binary_logloss: 0.126493	valid_1's auc: 0.839983	valid_1's binary_logloss: 0.13264
# [82]	training's auc: 0.880525	training's binary_logloss: 0.126332	valid_1's auc: 0.840031	valid_1's binary_logloss: 0.13258
# [83]	training's auc: 0.880778	training's binary_logloss: 0.126193	valid_1's auc: 0.840078	valid_1's binary_logloss: 0.132538
# [84]	training's auc: 0.88127	training's binary_logloss: 0.126043	valid_1's auc: 0.840048	valid_1's binary_logloss: 0.132489
# [85]	training's auc: 0.881621	training's binary_logloss: 0.125901	valid_1's auc: 0.839964	valid_1's binary_logloss: 0.13245
# [86]	training's auc: 0.881992	training's binary_logloss: 0.125763	valid_1's auc: 0.839962	valid_1's binary_logloss: 0.132406
# [87]	training's auc: 0.882242	training's binary_logloss: 0.125627	valid_1's auc: 0.840069	valid_1's binary_logloss: 0.132348
# [88]	training's auc: 0.882658	training's binary_logloss: 0.125492	valid_1's auc: 0.840594	valid_1's binary_logloss: 0.132292
# [89]	training's auc: 0.882969	training's binary_logloss: 0.125347	valid_1's auc: 0.840633	valid_1's binary_logloss: 0.132254
# [90]	training's auc: 0.883273	training's binary_logloss: 0.12522	valid_1's auc: 0.840661	valid_1's binary_logloss: 0.13223
# [91]	training's auc: 0.883564	training's binary_logloss: 0.125095	valid_1's auc: 0.840877	valid_1's binary_logloss: 0.132182
# [92]	training's auc: 0.88383	training's binary_logloss: 0.124957	valid_1's auc: 0.840844	valid_1's binary_logloss: 0.132149
# [93]	training's auc: 0.884033	training's binary_logloss: 0.124844	valid_1's auc: 0.840947	valid_1's binary_logloss: 0.132115
# [94]	training's auc: 0.884275	training's binary_logloss: 0.124715	valid_1's auc: 0.841294	valid_1's binary_logloss: 0.132067
# [95]	training's auc: 0.884728	training's binary_logloss: 0.124574	valid_1's auc: 0.841386	valid_1's binary_logloss: 0.132039
# [96]	training's auc: 0.885022	training's binary_logloss: 0.124432	valid_1's auc: 0.841391	valid_1's binary_logloss: 0.132013
# [97]	training's auc: 0.885196	training's binary_logloss: 0.124304	valid_1's auc: 0.841727	valid_1's binary_logloss: 0.131993
# [98]	training's auc: 0.885538	training's binary_logloss: 0.124173	valid_1's auc: 0.841851	valid_1's binary_logloss: 0.131953
# [99]	training's auc: 0.885722	training's binary_logloss: 0.124062	valid_1's auc: 0.841965	valid_1's binary_logloss: 0.131927
# [100]	training's auc: 0.88607	training's binary_logloss: 0.123941	valid_1's auc: 0.842028	valid_1's binary_logloss: 0.131891
# [1]	training's auc: 0.831993	training's binary_logloss: 0.163174	valid_1's auc: 0.81718	valid_1's binary_logloss: 0.166459
# [2]	training's auc: 0.83306	training's binary_logloss: 0.16113	valid_1's auc: 0.817681	valid_1's binary_logloss: 0.164572
# [3]	training's auc: 0.833982	training's binary_logloss: 0.159293	valid_1's auc: 0.81777	valid_1's binary_logloss: 0.162926
# [4]	training's auc: 0.837459	training's binary_logloss: 0.15764	valid_1's auc: 0.819616	valid_1's binary_logloss: 0.161412
# [5]	training's auc: 0.838476	training's binary_logloss: 0.156102	valid_1's auc: 0.819979	valid_1's binary_logloss: 0.160026
# [6]	training's auc: 0.840912	training's binary_logloss: 0.154684	valid_1's auc: 0.820701	valid_1's binary_logloss: 0.158743
# [7]	training's auc: 0.841665	training's binary_logloss: 0.153372	valid_1's auc: 0.821213	valid_1's binary_logloss: 0.157579
# [8]	training's auc: 0.842469	training's binary_logloss: 0.152147	valid_1's auc: 0.821128	valid_1's binary_logloss: 0.156522
# [9]	training's auc: 0.843029	training's binary_logloss: 0.15101	valid_1's auc: 0.821362	valid_1's binary_logloss: 0.155548
# [10]	training's auc: 0.846132	training's binary_logloss: 0.149959	valid_1's auc: 0.824069	valid_1's binary_logloss: 0.154603
# [11]	training's auc: 0.849471	training's binary_logloss: 0.14898	valid_1's auc: 0.826602	valid_1's binary_logloss: 0.153738
# [12]	training's auc: 0.850193	training's binary_logloss: 0.148046	valid_1's auc: 0.826449	valid_1's binary_logloss: 0.152939
# [13]	training's auc: 0.85162	training's binary_logloss: 0.147152	valid_1's auc: 0.826775	valid_1's binary_logloss: 0.152163
# [14]	training's auc: 0.852944	training's binary_logloss: 0.146308	valid_1's auc: 0.828004	valid_1's binary_logloss: 0.151414
# [15]	training's auc: 0.854295	training's binary_logloss: 0.145506	valid_1's auc: 0.828507	valid_1's binary_logloss: 0.150744
# [16]	training's auc: 0.855179	training's binary_logloss: 0.14475	valid_1's auc: 0.828737	valid_1's binary_logloss: 0.150112
# [17]	training's auc: 0.857508	training's binary_logloss: 0.143992	valid_1's auc: 0.831548	valid_1's binary_logloss: 0.149467
# [18]	training's auc: 0.858183	training's binary_logloss: 0.143264	valid_1's auc: 0.832172	valid_1's binary_logloss: 0.148866
# [19]	training's auc: 0.858877	training's binary_logloss: 0.14259	valid_1's auc: 0.832428	valid_1's binary_logloss: 0.148305
# [20]	training's auc: 0.859657	training's binary_logloss: 0.141924	valid_1's auc: 0.833474	valid_1's binary_logloss: 0.147752
# [21]	training's auc: 0.86036	training's binary_logloss: 0.141297	valid_1's auc: 0.833373	valid_1's binary_logloss: 0.147237
# [22]	training's auc: 0.860626	training's binary_logloss: 0.140692	valid_1's auc: 0.833495	valid_1's binary_logloss: 0.14673
# [23]	training's auc: 0.860926	training's binary_logloss: 0.140114	valid_1's auc: 0.833647	valid_1's binary_logloss: 0.146273
# [24]	training's auc: 0.861348	training's binary_logloss: 0.139554	valid_1's auc: 0.833854	valid_1's binary_logloss: 0.145831
# [25]	training's auc: 0.861715	training's binary_logloss: 0.13902	valid_1's auc: 0.833797	valid_1's binary_logloss: 0.1454
# [26]	training's auc: 0.862302	training's binary_logloss: 0.138521	valid_1's auc: 0.833795	valid_1's binary_logloss: 0.145001
# [27]	training's auc: 0.862504	training's binary_logloss: 0.138039	valid_1's auc: 0.834182	valid_1's binary_logloss: 0.144614
# [28]	training's auc: 0.862761	training's binary_logloss: 0.137573	valid_1's auc: 0.834362	valid_1's binary_logloss: 0.144257
# [29]	training's auc: 0.862911	training's binary_logloss: 0.137127	valid_1's auc: 0.83456	valid_1's binary_logloss: 0.143892
# [30]	training's auc: 0.863051	training's binary_logloss: 0.136694	valid_1's auc: 0.834571	valid_1's binary_logloss: 0.143561
# [31]	training's auc: 0.863529	training's binary_logloss: 0.136288	valid_1's auc: 0.834362	valid_1's binary_logloss: 0.143261
# [32]	training's auc: 0.86368	training's binary_logloss: 0.135891	valid_1's auc: 0.834542	valid_1's binary_logloss: 0.142968
# [33]	training's auc: 0.864334	training's binary_logloss: 0.135466	valid_1's auc: 0.834526	valid_1's binary_logloss: 0.142674
# [34]	training's auc: 0.864661	training's binary_logloss: 0.135089	valid_1's auc: 0.834471	valid_1's binary_logloss: 0.1424
# [35]	training's auc: 0.865254	training's binary_logloss: 0.134695	valid_1's auc: 0.834286	valid_1's binary_logloss: 0.142157
# [36]	training's auc: 0.86607	training's binary_logloss: 0.134325	valid_1's auc: 0.834875	valid_1's binary_logloss: 0.1419
# [37]	training's auc: 0.866475	training's binary_logloss: 0.13397	valid_1's auc: 0.834832	valid_1's binary_logloss: 0.14166
# [38]	training's auc: 0.867176	training's binary_logloss: 0.133614	valid_1's auc: 0.834912	valid_1's binary_logloss: 0.141432
# [39]	training's auc: 0.867671	training's binary_logloss: 0.133264	valid_1's auc: 0.835208	valid_1's binary_logloss: 0.1412
# [40]	training's auc: 0.868018	training's binary_logloss: 0.132933	valid_1's auc: 0.835072	valid_1's binary_logloss: 0.140974
# [41]	training's auc: 0.868542	training's binary_logloss: 0.132603	valid_1's auc: 0.834922	valid_1's binary_logloss: 0.140783
# [42]	training's auc: 0.869022	training's binary_logloss: 0.132285	valid_1's auc: 0.835075	valid_1's binary_logloss: 0.140576
# [43]	training's auc: 0.869336	training's binary_logloss: 0.131985	valid_1's auc: 0.835163	valid_1's binary_logloss: 0.140393
# [44]	training's auc: 0.869813	training's binary_logloss: 0.131689	valid_1's auc: 0.834945	valid_1's binary_logloss: 0.140221
# [45]	training's auc: 0.87053	training's binary_logloss: 0.131396	valid_1's auc: 0.835208	valid_1's binary_logloss: 0.140034
# [46]	training's auc: 0.870805	training's binary_logloss: 0.131119	valid_1's auc: 0.835382	valid_1's binary_logloss: 0.139859
# [47]	training's auc: 0.871128	training's binary_logloss: 0.130837	valid_1's auc: 0.835617	valid_1's binary_logloss: 0.139676
# [48]	training's auc: 0.871401	training's binary_logloss: 0.130574	valid_1's auc: 0.83547	valid_1's binary_logloss: 0.139523
# [49]	training's auc: 0.872097	training's binary_logloss: 0.130301	valid_1's auc: 0.835625	valid_1's binary_logloss: 0.139355
# [50]	training's auc: 0.872659	training's binary_logloss: 0.130039	valid_1's auc: 0.835806	valid_1's binary_logloss: 0.13921
# [51]	training's auc: 0.873208	training's binary_logloss: 0.129777	valid_1's auc: 0.835875	valid_1's binary_logloss: 0.139071
# [52]	training's auc: 0.873733	training's binary_logloss: 0.129539	valid_1's auc: 0.836149	valid_1's binary_logloss: 0.138934
# [53]	training's auc: 0.874361	training's binary_logloss: 0.129278	valid_1's auc: 0.836099	valid_1's binary_logloss: 0.138807
# [54]	training's auc: 0.874979	training's binary_logloss: 0.129032	valid_1's auc: 0.836334	valid_1's binary_logloss: 0.138683
# [55]	training's auc: 0.875469	training's binary_logloss: 0.128799	valid_1's auc: 0.836309	valid_1's binary_logloss: 0.138563
# [56]	training's auc: 0.875874	training's binary_logloss: 0.128565	valid_1's auc: 0.836386	valid_1's binary_logloss: 0.13843
# [57]	training's auc: 0.876318	training's binary_logloss: 0.128327	valid_1's auc: 0.836515	valid_1's binary_logloss: 0.13831
# [58]	training's auc: 0.876658	training's binary_logloss: 0.128105	valid_1's auc: 0.836408	valid_1's binary_logloss: 0.138199
# [59]	training's auc: 0.877006	training's binary_logloss: 0.12789	valid_1's auc: 0.836355	valid_1's binary_logloss: 0.138101
# [60]	training's auc: 0.877379	training's binary_logloss: 0.127666	valid_1's auc: 0.836461	valid_1's binary_logloss: 0.137996
# [61]	training's auc: 0.877839	training's binary_logloss: 0.127441	valid_1's auc: 0.836393	valid_1's binary_logloss: 0.137903
# [62]	training's auc: 0.878106	training's binary_logloss: 0.12724	valid_1's auc: 0.836439	valid_1's binary_logloss: 0.137809
# [63]	training's auc: 0.878688	training's binary_logloss: 0.127025	valid_1's auc: 0.836528	valid_1's binary_logloss: 0.137715
# [64]	training's auc: 0.87919	training's binary_logloss: 0.126834	valid_1's auc: 0.836493	valid_1's binary_logloss: 0.137642
# [65]	training's auc: 0.879501	training's binary_logloss: 0.126649	valid_1's auc: 0.836483	valid_1's binary_logloss: 0.137569
# [66]	training's auc: 0.879822	training's binary_logloss: 0.126462	valid_1's auc: 0.836534	valid_1's binary_logloss: 0.137481
# [67]	training's auc: 0.880137	training's binary_logloss: 0.126274	valid_1's auc: 0.836515	valid_1's binary_logloss: 0.137414
# [68]	training's auc: 0.88051	training's binary_logloss: 0.126092	valid_1's auc: 0.836466	valid_1's binary_logloss: 0.137338
# [69]	training's auc: 0.881003	training's binary_logloss: 0.1259	valid_1's auc: 0.836471	valid_1's binary_logloss: 0.137266
# [70]	training's auc: 0.881333	training's binary_logloss: 0.125721	valid_1's auc: 0.836652	valid_1's binary_logloss: 0.137198
# [71]	training's auc: 0.881614	training's binary_logloss: 0.125542	valid_1's auc: 0.836819	valid_1's binary_logloss: 0.137119
# [72]	training's auc: 0.881941	training's binary_logloss: 0.125363	valid_1's auc: 0.836747	valid_1's binary_logloss: 0.13705
# [73]	training's auc: 0.882231	training's binary_logloss: 0.125198	valid_1's auc: 0.836898	valid_1's binary_logloss: 0.136973
# [74]	training's auc: 0.882543	training's binary_logloss: 0.125031	valid_1's auc: 0.836864	valid_1's binary_logloss: 0.136923
# [75]	training's auc: 0.882833	training's binary_logloss: 0.124875	valid_1's auc: 0.83677	valid_1's binary_logloss: 0.136877
# [76]	training's auc: 0.883188	training's binary_logloss: 0.12472	valid_1's auc: 0.836719	valid_1's binary_logloss: 0.136827
# [77]	training's auc: 0.883428	training's binary_logloss: 0.124576	valid_1's auc: 0.836674	valid_1's binary_logloss: 0.136777
# [78]	training's auc: 0.883642	training's binary_logloss: 0.124428	valid_1's auc: 0.836666	valid_1's binary_logloss: 0.136728
# [79]	training's auc: 0.884021	training's binary_logloss: 0.124263	valid_1's auc: 0.836687	valid_1's binary_logloss: 0.13668
# [80]	training's auc: 0.884279	training's binary_logloss: 0.124102	valid_1's auc: 0.836755	valid_1's binary_logloss: 0.136634
# [81]	training's auc: 0.885099	training's binary_logloss: 0.123936	valid_1's auc: 0.837606	valid_1's binary_logloss: 0.1366
# [82]	training's auc: 0.885447	training's binary_logloss: 0.123788	valid_1's auc: 0.837746	valid_1's binary_logloss: 0.136532
# [83]	training's auc: 0.885669	training's binary_logloss: 0.123643	valid_1's auc: 0.837837	valid_1's binary_logloss: 0.13648
# [84]	training's auc: 0.886002	training's binary_logloss: 0.123508	valid_1's auc: 0.837651	valid_1's binary_logloss: 0.136455
# [85]	training's auc: 0.886287	training's binary_logloss: 0.123373	valid_1's auc: 0.837626	valid_1's binary_logloss: 0.136407
# [86]	training's auc: 0.886618	training's binary_logloss: 0.123223	valid_1's auc: 0.837525	valid_1's binary_logloss: 0.136377
# [87]	training's auc: 0.886979	training's binary_logloss: 0.123066	valid_1's auc: 0.837473	valid_1's binary_logloss: 0.136346
# [88]	training's auc: 0.887279	training's binary_logloss: 0.122935	valid_1's auc: 0.837389	valid_1's binary_logloss: 0.13632
# [89]	training's auc: 0.887542	training's binary_logloss: 0.122783	valid_1's auc: 0.837325	valid_1's binary_logloss: 0.136286
# [90]	training's auc: 0.887811	training's binary_logloss: 0.122639	valid_1's auc: 0.837232	valid_1's binary_logloss: 0.136266
# [91]	training's auc: 0.888153	training's binary_logloss: 0.122504	valid_1's auc: 0.837008	valid_1's binary_logloss: 0.136261
# [92]	training's auc: 0.888455	training's binary_logloss: 0.12237	valid_1's auc: 0.836945	valid_1's binary_logloss: 0.136232
# [93]	training's auc: 0.888772	training's binary_logloss: 0.122219	valid_1's auc: 0.837106	valid_1's binary_logloss: 0.136191
# [94]	training's auc: 0.889059	training's binary_logloss: 0.122094	valid_1's auc: 0.837084	valid_1's binary_logloss: 0.136166
# [95]	training's auc: 0.889491	training's binary_logloss: 0.121966	valid_1's auc: 0.836997	valid_1's binary_logloss: 0.136143
# [96]	training's auc: 0.889756	training's binary_logloss: 0.121829	valid_1's auc: 0.836994	valid_1's binary_logloss: 0.13613
# [97]	training's auc: 0.890043	training's binary_logloss: 0.121703	valid_1's auc: 0.836878	valid_1's binary_logloss: 0.136119
# [98]	training's auc: 0.890267	training's binary_logloss: 0.121575	valid_1's auc: 0.836861	valid_1's binary_logloss: 0.136105
# [99]	training's auc: 0.890549	training's binary_logloss: 0.121451	valid_1's auc: 0.836952	valid_1's binary_logloss: 0.136083
# [100]	training's auc: 0.890922	training's binary_logloss: 0.121328	valid_1's auc: 0.83708	valid_1's binary_logloss: 0.136042
# [1]	training's auc: 0.833716	training's binary_logloss: 0.163406	valid_1's auc: 0.823695	valid_1's binary_logloss: 0.166212
# [2]	training's auc: 0.834998	training's binary_logloss: 0.161403	valid_1's auc: 0.823718	valid_1's binary_logloss: 0.164401
# [3]	training's auc: 0.83775	training's binary_logloss: 0.159568	valid_1's auc: 0.825576	valid_1's binary_logloss: 0.162707
# [4]	training's auc: 0.839587	training's binary_logloss: 0.157895	valid_1's auc: 0.827659	valid_1's binary_logloss: 0.161165
# [5]	training's auc: 0.841552	training's binary_logloss: 0.156381	valid_1's auc: 0.829718	valid_1's binary_logloss: 0.159756
# [6]	training's auc: 0.841905	training's binary_logloss: 0.154978	valid_1's auc: 0.829876	valid_1's binary_logloss: 0.158473
# [7]	training's auc: 0.842462	training's binary_logloss: 0.153671	valid_1's auc: 0.830499	valid_1's binary_logloss: 0.15728
# [8]	training's auc: 0.843539	training's binary_logloss: 0.15246	valid_1's auc: 0.830378	valid_1's binary_logloss: 0.156202
# [9]	training's auc: 0.84432	training's binary_logloss: 0.151316	valid_1's auc: 0.830209	valid_1's binary_logloss: 0.155214
# [10]	training's auc: 0.846421	training's binary_logloss: 0.150255	valid_1's auc: 0.831571	valid_1's binary_logloss: 0.154302
# [11]	training's auc: 0.848532	training's binary_logloss: 0.149248	valid_1's auc: 0.832158	valid_1's binary_logloss: 0.153435
# [12]	training's auc: 0.850313	training's binary_logloss: 0.148295	valid_1's auc: 0.832646	valid_1's binary_logloss: 0.152597
# [13]	training's auc: 0.851276	training's binary_logloss: 0.147377	valid_1's auc: 0.832693	valid_1's binary_logloss: 0.151797
# [14]	training's auc: 0.852126	training's binary_logloss: 0.146502	valid_1's auc: 0.832444	valid_1's binary_logloss: 0.151076
# [15]	training's auc: 0.85294	training's binary_logloss: 0.145694	valid_1's auc: 0.833105	valid_1's binary_logloss: 0.150392
# [16]	training's auc: 0.853654	training's binary_logloss: 0.14493	valid_1's auc: 0.833454	valid_1's binary_logloss: 0.149756
# [17]	training's auc: 0.854064	training's binary_logloss: 0.144186	valid_1's auc: 0.833841	valid_1's binary_logloss: 0.149108
# [18]	training's auc: 0.854982	training's binary_logloss: 0.143483	valid_1's auc: 0.833666	valid_1's binary_logloss: 0.148541
# [19]	training's auc: 0.856419	training's binary_logloss: 0.1428	valid_1's auc: 0.834926	valid_1's binary_logloss: 0.14798
# [20]	training's auc: 0.857129	training's binary_logloss: 0.142154	valid_1's auc: 0.835454	valid_1's binary_logloss: 0.14743
# [21]	training's auc: 0.857755	training's binary_logloss: 0.141547	valid_1's auc: 0.835796	valid_1's binary_logloss: 0.146894
# [22]	training's auc: 0.858218	training's binary_logloss: 0.140969	valid_1's auc: 0.836144	valid_1's binary_logloss: 0.146385
# [23]	training's auc: 0.858764	training's binary_logloss: 0.14041	valid_1's auc: 0.836552	valid_1's binary_logloss: 0.14592
# [24]	training's auc: 0.859029	training's binary_logloss: 0.139888	valid_1's auc: 0.836841	valid_1's binary_logloss: 0.145465
# [25]	training's auc: 0.859389	training's binary_logloss: 0.139383	valid_1's auc: 0.837359	valid_1's binary_logloss: 0.145017
# [26]	training's auc: 0.859761	training's binary_logloss: 0.138894	valid_1's auc: 0.837606	valid_1's binary_logloss: 0.144624
# [27]	training's auc: 0.859929	training's binary_logloss: 0.13843	valid_1's auc: 0.837839	valid_1's binary_logloss: 0.144235
# [28]	training's auc: 0.861848	training's binary_logloss: 0.137978	valid_1's auc: 0.839818	valid_1's binary_logloss: 0.143853
# [29]	training's auc: 0.862884	training's binary_logloss: 0.137528	valid_1's auc: 0.839853	valid_1's binary_logloss: 0.14351
# [30]	training's auc: 0.863041	training's binary_logloss: 0.13709	valid_1's auc: 0.839937	valid_1's binary_logloss: 0.143184
# [31]	training's auc: 0.863249	training's binary_logloss: 0.136669	valid_1's auc: 0.840019	valid_1's binary_logloss: 0.14288
# [32]	training's auc: 0.863563	training's binary_logloss: 0.13626	valid_1's auc: 0.839788	valid_1's binary_logloss: 0.142596
# [33]	training's auc: 0.863816	training's binary_logloss: 0.135867	valid_1's auc: 0.839756	valid_1's binary_logloss: 0.142317
# [34]	training's auc: 0.863931	training's binary_logloss: 0.135481	valid_1's auc: 0.839526	valid_1's binary_logloss: 0.142051
# [35]	training's auc: 0.86452	training's binary_logloss: 0.135107	valid_1's auc: 0.839529	valid_1's binary_logloss: 0.141795
# [36]	training's auc: 0.864728	training's binary_logloss: 0.134759	valid_1's auc: 0.839419	valid_1's binary_logloss: 0.141558
# [37]	training's auc: 0.864864	training's binary_logloss: 0.134416	valid_1's auc: 0.839331	valid_1's binary_logloss: 0.141329
# [38]	training's auc: 0.865156	training's binary_logloss: 0.134081	valid_1's auc: 0.839125	valid_1's binary_logloss: 0.141127
# [39]	training's auc: 0.865531	training's binary_logloss: 0.133762	valid_1's auc: 0.838882	valid_1's binary_logloss: 0.140918
# [40]	training's auc: 0.866037	training's binary_logloss: 0.133425	valid_1's auc: 0.838963	valid_1's binary_logloss: 0.140706
# [41]	training's auc: 0.86632	training's binary_logloss: 0.133124	valid_1's auc: 0.838778	valid_1's binary_logloss: 0.140507
# [42]	training's auc: 0.866627	training's binary_logloss: 0.132828	valid_1's auc: 0.83889	valid_1's binary_logloss: 0.140323
# [43]	training's auc: 0.866962	training's binary_logloss: 0.132544	valid_1's auc: 0.838451	valid_1's binary_logloss: 0.140166
# [44]	training's auc: 0.867188	training's binary_logloss: 0.132258	valid_1's auc: 0.838515	valid_1's binary_logloss: 0.139981
# [45]	training's auc: 0.867659	training's binary_logloss: 0.131957	valid_1's auc: 0.838602	valid_1's binary_logloss: 0.139794
# [46]	training's auc: 0.867872	training's binary_logloss: 0.131696	valid_1's auc: 0.838388	valid_1's binary_logloss: 0.139632
# [47]	training's auc: 0.868276	training's binary_logloss: 0.13142	valid_1's auc: 0.838496	valid_1's binary_logloss: 0.139468
# [48]	training's auc: 0.868625	training's binary_logloss: 0.131151	valid_1's auc: 0.838621	valid_1's binary_logloss: 0.139293
# [49]	training's auc: 0.86895	training's binary_logloss: 0.130894	valid_1's auc: 0.838713	valid_1's binary_logloss: 0.139129
# [50]	training's auc: 0.869403	training's binary_logloss: 0.130632	valid_1's auc: 0.838897	valid_1's binary_logloss: 0.138943
# [51]	training's auc: 0.869921	training's binary_logloss: 0.130385	valid_1's auc: 0.838942	valid_1's binary_logloss: 0.138795
# [52]	training's auc: 0.870155	training's binary_logloss: 0.130149	valid_1's auc: 0.83915	valid_1's binary_logloss: 0.138634
# [53]	training's auc: 0.870578	training's binary_logloss: 0.12993	valid_1's auc: 0.839291	valid_1's binary_logloss: 0.138491
# [54]	training's auc: 0.871342	training's binary_logloss: 0.1297	valid_1's auc: 0.839427	valid_1's binary_logloss: 0.138354
# [55]	training's auc: 0.871533	training's binary_logloss: 0.129481	valid_1's auc: 0.839482	valid_1's binary_logloss: 0.138224
# [56]	training's auc: 0.871968	training's binary_logloss: 0.129264	valid_1's auc: 0.839475	valid_1's binary_logloss: 0.138101
# [57]	training's auc: 0.872225	training's binary_logloss: 0.129042	valid_1's auc: 0.839443	valid_1's binary_logloss: 0.138001
# [58]	training's auc: 0.872442	training's binary_logloss: 0.128843	valid_1's auc: 0.839338	valid_1's binary_logloss: 0.137884
# [59]	training's auc: 0.872842	training's binary_logloss: 0.128621	valid_1's auc: 0.839472	valid_1's binary_logloss: 0.137792
# [60]	training's auc: 0.873251	training's binary_logloss: 0.128394	valid_1's auc: 0.839471	valid_1's binary_logloss: 0.137702
# [61]	training's auc: 0.873739	training's binary_logloss: 0.128191	valid_1's auc: 0.839396	valid_1's binary_logloss: 0.13762
# [1]	training's auc: 0.836918	training's binary_logloss: 0.155765	valid_1's auc: 0.817936	valid_1's binary_logloss: 0.152744
# [2]	training's auc: 0.849625	training's binary_logloss: 0.148812	valid_1's auc: 0.823632	valid_1's binary_logloss: 0.147409
# [3]	training's auc: 0.854943	training's binary_logloss: 0.143897	valid_1's auc: 0.823702	valid_1's binary_logloss: 0.143971
# [4]	training's auc: 0.862105	training's binary_logloss: 0.140177	valid_1's auc: 0.828653	valid_1's binary_logloss: 0.141332
# [5]	training's auc: 0.865151	training's binary_logloss: 0.137165	valid_1's auc: 0.828912	valid_1's binary_logloss: 0.13949
# [6]	training's auc: 0.8692	training's binary_logloss: 0.134678	valid_1's auc: 0.831259	valid_1's binary_logloss: 0.13812
# [7]	training's auc: 0.872022	training's binary_logloss: 0.132656	valid_1's auc: 0.833341	valid_1's binary_logloss: 0.136968
# [8]	training's auc: 0.874759	training's binary_logloss: 0.130844	valid_1's auc: 0.834482	valid_1's binary_logloss: 0.135976
# [9]	training's auc: 0.876784	training's binary_logloss: 0.129244	valid_1's auc: 0.83445	valid_1's binary_logloss: 0.135231
# [10]	training's auc: 0.87954	training's binary_logloss: 0.127794	valid_1's auc: 0.835637	valid_1's binary_logloss: 0.134535
# [11]	training's auc: 0.883149	training's binary_logloss: 0.126474	valid_1's auc: 0.837258	valid_1's binary_logloss: 0.133839
# [12]	training's auc: 0.885397	training's binary_logloss: 0.12529	valid_1's auc: 0.837475	valid_1's binary_logloss: 0.133541
# [13]	training's auc: 0.887004	training's binary_logloss: 0.124244	valid_1's auc: 0.837449	valid_1's binary_logloss: 0.133268
# [14]	training's auc: 0.890876	training's binary_logloss: 0.123167	valid_1's auc: 0.837774	valid_1's binary_logloss: 0.133043
# [15]	training's auc: 0.892724	training's binary_logloss: 0.122201	valid_1's auc: 0.838608	valid_1's binary_logloss: 0.132748
# [16]	training's auc: 0.895075	training's binary_logloss: 0.121299	valid_1's auc: 0.838034	valid_1's binary_logloss: 0.132669
# [17]	training's auc: 0.896867	training's binary_logloss: 0.12048	valid_1's auc: 0.838781	valid_1's binary_logloss: 0.132496
# [18]	training's auc: 0.898596	training's binary_logloss: 0.119637	valid_1's auc: 0.839098	valid_1's binary_logloss: 0.132389
# [19]	training's auc: 0.900951	training's binary_logloss: 0.118784	valid_1's auc: 0.838577	valid_1's binary_logloss: 0.132346
# [20]	training's auc: 0.902996	training's binary_logloss: 0.117962	valid_1's auc: 0.839049	valid_1's binary_logloss: 0.132179
# [21]	training's auc: 0.904789	training's binary_logloss: 0.117106	valid_1's auc: 0.839215	valid_1's binary_logloss: 0.132157
# [22]	training's auc: 0.906142	training's binary_logloss: 0.116419	valid_1's auc: 0.839676	valid_1's binary_logloss: 0.132047
# [23]	training's auc: 0.907861	training's binary_logloss: 0.115662	valid_1's auc: 0.839478	valid_1's binary_logloss: 0.13198
# [24]	training's auc: 0.909461	training's binary_logloss: 0.115055	valid_1's auc: 0.839387	valid_1's binary_logloss: 0.132013
# [25]	training's auc: 0.910768	training's binary_logloss: 0.114463	valid_1's auc: 0.838798	valid_1's binary_logloss: 0.132066
# [26]	training's auc: 0.912213	training's binary_logloss: 0.11378	valid_1's auc: 0.839269	valid_1's binary_logloss: 0.131953
# [27]	training's auc: 0.91339	training's binary_logloss: 0.113153	valid_1's auc: 0.839622	valid_1's binary_logloss: 0.131861
# [28]	training's auc: 0.915052	training's binary_logloss: 0.112501	valid_1's auc: 0.839671	valid_1's binary_logloss: 0.131877
# [29]	training's auc: 0.916382	training's binary_logloss: 0.111814	valid_1's auc: 0.839733	valid_1's binary_logloss: 0.131901
# [30]	training's auc: 0.918321	training's binary_logloss: 0.111208	valid_1's auc: 0.839632	valid_1's binary_logloss: 0.131874
# [31]	training's auc: 0.91984	training's binary_logloss: 0.110635	valid_1's auc: 0.840136	valid_1's binary_logloss: 0.131803
# [32]	training's auc: 0.921182	training's binary_logloss: 0.109975	valid_1's auc: 0.840185	valid_1's binary_logloss: 0.131814
# [33]	training's auc: 0.922551	training's binary_logloss: 0.109359	valid_1's auc: 0.839665	valid_1's binary_logloss: 0.131938
# [34]	training's auc: 0.923594	training's binary_logloss: 0.108846	valid_1's auc: 0.839693	valid_1's binary_logloss: 0.131943
# [35]	training's auc: 0.924504	training's binary_logloss: 0.108331	valid_1's auc: 0.839362	valid_1's binary_logloss: 0.131986
# [36]	training's auc: 0.926562	training's binary_logloss: 0.107764	valid_1's auc: 0.839215	valid_1's binary_logloss: 0.132036
# [37]	training's auc: 0.927677	training's binary_logloss: 0.107283	valid_1's auc: 0.839191	valid_1's binary_logloss: 0.132045
# [38]	training's auc: 0.928417	training's binary_logloss: 0.106845	valid_1's auc: 0.839056	valid_1's binary_logloss: 0.132108
# [39]	training's auc: 0.929078	training's binary_logloss: 0.106342	valid_1's auc: 0.83902	valid_1's binary_logloss: 0.132191
# [40]	training's auc: 0.929775	training's binary_logloss: 0.105935	valid_1's auc: 0.839019	valid_1's binary_logloss: 0.132196
# [41]	training's auc: 0.930261	training's binary_logloss: 0.10557	valid_1's auc: 0.838871	valid_1's binary_logloss: 0.132217
# [42]	training's auc: 0.931741	training's binary_logloss: 0.104952	valid_1's auc: 0.83849	valid_1's binary_logloss: 0.132312
# [43]	training's auc: 0.932402	training's binary_logloss: 0.1045	valid_1's auc: 0.838453	valid_1's binary_logloss: 0.132287
# [44]	training's auc: 0.933481	training's binary_logloss: 0.104065	valid_1's auc: 0.838215	valid_1's binary_logloss: 0.13236
# [45]	training's auc: 0.934243	training's binary_logloss: 0.103739	valid_1's auc: 0.837823	valid_1's binary_logloss: 0.132432
# [46]	training's auc: 0.934687	training's binary_logloss: 0.103379	valid_1's auc: 0.838148	valid_1's binary_logloss: 0.132427
# [47]	training's auc: 0.935171	training's binary_logloss: 0.10302	valid_1's auc: 0.838098	valid_1's binary_logloss: 0.132465
# [48]	training's auc: 0.935696	training's binary_logloss: 0.102619	valid_1's auc: 0.837682	valid_1's binary_logloss: 0.132604
# [49]	training's auc: 0.936135	training's binary_logloss: 0.10228	valid_1's auc: 0.837463	valid_1's binary_logloss: 0.13266
# [50]	training's auc: 0.93652	training's binary_logloss: 0.101993	valid_1's auc: 0.837248	valid_1's binary_logloss: 0.132732
# [51]	training's auc: 0.937253	training's binary_logloss: 0.101696	valid_1's auc: 0.836605	valid_1's binary_logloss: 0.132858
# [52]	training's auc: 0.937986	training's binary_logloss: 0.10127	valid_1's auc: 0.836188	valid_1's binary_logloss: 0.132973
# [53]	training's auc: 0.938451	training's binary_logloss: 0.100912	valid_1's auc: 0.836484	valid_1's binary_logloss: 0.132949
# [54]	training's auc: 0.938788	training's binary_logloss: 0.100582	valid_1's auc: 0.836254	valid_1's binary_logloss: 0.132976
# [55]	training's auc: 0.939819	training's binary_logloss: 0.100113	valid_1's auc: 0.836035	valid_1's binary_logloss: 0.133034
# [56]	training's auc: 0.940365	training's binary_logloss: 0.0996967	valid_1's auc: 0.836202	valid_1's binary_logloss: 0.133041
# [57]	training's auc: 0.941198	training's binary_logloss: 0.099392	valid_1's auc: 0.836344	valid_1's binary_logloss: 0.133031
# [58]	training's auc: 0.94218	training's binary_logloss: 0.098927	valid_1's auc: 0.83615	valid_1's binary_logloss: 0.133103
# [59]	training's auc: 0.942465	training's binary_logloss: 0.0986595	valid_1's auc: 0.835852	valid_1's binary_logloss: 0.133171
# [60]	training's auc: 0.94289	training's binary_logloss: 0.0983253	valid_1's auc: 0.835714	valid_1's binary_logloss: 0.133251
# [61]	training's auc: 0.944162	training's binary_logloss: 0.0978698	valid_1's auc: 0.835681	valid_1's binary_logloss: 0.133304
# [1]	training's auc: 0.837518	training's binary_logloss: 0.152756	valid_1's auc: 0.813528	valid_1's binary_logloss: 0.157778
# [2]	training's auc: 0.850734	training's binary_logloss: 0.146216	valid_1's auc: 0.821052	valid_1's binary_logloss: 0.152505
# [3]	training's auc: 0.861381	training's binary_logloss: 0.141559	valid_1's auc: 0.825031	valid_1's binary_logloss: 0.148954
# [4]	training's auc: 0.866077	training's binary_logloss: 0.137816	valid_1's auc: 0.828613	valid_1's binary_logloss: 0.146203
# [5]	training's auc: 0.86997	training's binary_logloss: 0.134983	valid_1's auc: 0.830609	valid_1's binary_logloss: 0.144175
# [6]	training's auc: 0.873717	training's binary_logloss: 0.132507	valid_1's auc: 0.831156	valid_1's binary_logloss: 0.14252
# [7]	training's auc: 0.876199	training's binary_logloss: 0.130429	valid_1's auc: 0.830384	valid_1's binary_logloss: 0.141465
# [8]	training's auc: 0.879431	training's binary_logloss: 0.128656	valid_1's auc: 0.831816	valid_1's binary_logloss: 0.140646
# [9]	training's auc: 0.882052	training's binary_logloss: 0.127004	valid_1's auc: 0.832578	valid_1's binary_logloss: 0.139724
# [10]	training's auc: 0.8838	training's binary_logloss: 0.125544	valid_1's auc: 0.832469	valid_1's binary_logloss: 0.139178
# [11]	training's auc: 0.886969	training's binary_logloss: 0.124117	valid_1's auc: 0.833081	valid_1's binary_logloss: 0.138776
# [12]	training's auc: 0.89029	training's binary_logloss: 0.122815	valid_1's auc: 0.833531	valid_1's binary_logloss: 0.13834
# [13]	training's auc: 0.892589	training's binary_logloss: 0.121672	valid_1's auc: 0.832795	valid_1's binary_logloss: 0.138177
# [14]	training's auc: 0.894571	training's binary_logloss: 0.120657	valid_1's auc: 0.833215	valid_1's binary_logloss: 0.137951
# [15]	training's auc: 0.896589	training's binary_logloss: 0.119692	valid_1's auc: 0.832743	valid_1's binary_logloss: 0.137859
# [16]	training's auc: 0.898711	training's binary_logloss: 0.118686	valid_1's auc: 0.832777	valid_1's binary_logloss: 0.13768
# [17]	training's auc: 0.90098	training's binary_logloss: 0.117737	valid_1's auc: 0.832529	valid_1's binary_logloss: 0.137611
# [18]	training's auc: 0.903193	training's binary_logloss: 0.116838	valid_1's auc: 0.83307	valid_1's binary_logloss: 0.137529
# [19]	training's auc: 0.904913	training's binary_logloss: 0.116013	valid_1's auc: 0.832823	valid_1's binary_logloss: 0.13753
# [20]	training's auc: 0.907387	training's binary_logloss: 0.115093	valid_1's auc: 0.833413	valid_1's binary_logloss: 0.137355
# [21]	training's auc: 0.908669	training's binary_logloss: 0.114407	valid_1's auc: 0.833498	valid_1's binary_logloss: 0.137268
# [22]	training's auc: 0.910086	training's binary_logloss: 0.113767	valid_1's auc: 0.833668	valid_1's binary_logloss: 0.137219
# [23]	training's auc: 0.912844	training's binary_logloss: 0.113025	valid_1's auc: 0.833356	valid_1's binary_logloss: 0.137265
# [24]	training's auc: 0.914494	training's binary_logloss: 0.112313	valid_1's auc: 0.833542	valid_1's binary_logloss: 0.137181
# [25]	training's auc: 0.915983	training's binary_logloss: 0.111492	valid_1's auc: 0.833649	valid_1's binary_logloss: 0.137165
# [26]	training's auc: 0.917563	training's binary_logloss: 0.110815	valid_1's auc: 0.833442	valid_1's binary_logloss: 0.137181
# [27]	training's auc: 0.919168	training's binary_logloss: 0.110255	valid_1's auc: 0.833158	valid_1's binary_logloss: 0.137251
# [28]	training's auc: 0.92084	training's binary_logloss: 0.10958	valid_1's auc: 0.833021	valid_1's binary_logloss: 0.137335
# [29]	training's auc: 0.922279	training's binary_logloss: 0.109027	valid_1's auc: 0.832656	valid_1's binary_logloss: 0.137389
# [30]	training's auc: 0.923245	training's binary_logloss: 0.108538	valid_1's auc: 0.83258	valid_1's binary_logloss: 0.137415
# [31]	training's auc: 0.924469	training's binary_logloss: 0.107908	valid_1's auc: 0.832112	valid_1's binary_logloss: 0.137583
# [32]	training's auc: 0.92565	training's binary_logloss: 0.107451	valid_1's auc: 0.831826	valid_1's binary_logloss: 0.137647
# [33]	training's auc: 0.926592	training's binary_logloss: 0.106908	valid_1's auc: 0.831659	valid_1's binary_logloss: 0.137684
# [34]	training's auc: 0.927528	training's binary_logloss: 0.106403	valid_1's auc: 0.831729	valid_1's binary_logloss: 0.13768
# [35]	training's auc: 0.928263	training's binary_logloss: 0.105916	valid_1's auc: 0.831101	valid_1's binary_logloss: 0.137813
# [36]	training's auc: 0.929352	training's binary_logloss: 0.10532	valid_1's auc: 0.830925	valid_1's binary_logloss: 0.137871
# [37]	training's auc: 0.930075	training's binary_logloss: 0.104815	valid_1's auc: 0.830708	valid_1's binary_logloss: 0.137973
# [38]	training's auc: 0.930971	training's binary_logloss: 0.104365	valid_1's auc: 0.830411	valid_1's binary_logloss: 0.138049
# [39]	training's auc: 0.93175	training's binary_logloss: 0.103864	valid_1's auc: 0.830599	valid_1's binary_logloss: 0.138054
# [40]	training's auc: 0.932771	training's binary_logloss: 0.103345	valid_1's auc: 0.829939	valid_1's binary_logloss: 0.138231
# [41]	training's auc: 0.933214	training's binary_logloss: 0.102968	valid_1's auc: 0.830067	valid_1's binary_logloss: 0.138277
# [42]	training's auc: 0.934072	training's binary_logloss: 0.102637	valid_1's auc: 0.829603	valid_1's binary_logloss: 0.138437
# [43]	training's auc: 0.934699	training's binary_logloss: 0.102208	valid_1's auc: 0.829533	valid_1's binary_logloss: 0.138509
# [44]	training's auc: 0.935037	training's binary_logloss: 0.101869	valid_1's auc: 0.829624	valid_1's binary_logloss: 0.13849
# [45]	training's auc: 0.935434	training's binary_logloss: 0.101529	valid_1's auc: 0.829585	valid_1's binary_logloss: 0.138505
# [46]	training's auc: 0.935905	training's binary_logloss: 0.101199	valid_1's auc: 0.829569	valid_1's binary_logloss: 0.13856
# [47]	training's auc: 0.936417	training's binary_logloss: 0.100778	valid_1's auc: 0.829533	valid_1's binary_logloss: 0.138636
# [48]	training's auc: 0.936945	training's binary_logloss: 0.100392	valid_1's auc: 0.829014	valid_1's binary_logloss: 0.138766
# [49]	training's auc: 0.938015	training's binary_logloss: 0.0999352	valid_1's auc: 0.828588	valid_1's binary_logloss: 0.138902
# [50]	training's auc: 0.938577	training's binary_logloss: 0.0996303	valid_1's auc: 0.828565	valid_1's binary_logloss: 0.138947
# [51]	training's auc: 0.939497	training's binary_logloss: 0.0991486	valid_1's auc: 0.829153	valid_1's binary_logloss: 0.138901
# [52]	training's auc: 0.939868	training's binary_logloss: 0.0987852	valid_1's auc: 0.829335	valid_1's binary_logloss: 0.138905
# [1]	training's auc: 0.840722	training's binary_logloss: 0.15344	valid_1's auc: 0.826206	valid_1's binary_logloss: 0.157823
# [2]	training's auc: 0.848971	training's binary_logloss: 0.146749	valid_1's auc: 0.829223	valid_1's binary_logloss: 0.152259
# [3]	training's auc: 0.858197	training's binary_logloss: 0.141879	valid_1's auc: 0.828889	valid_1's binary_logloss: 0.148566
# [4]	training's auc: 0.861254	training's binary_logloss: 0.138291	valid_1's auc: 0.832495	valid_1's binary_logloss: 0.145984
# [5]	training's auc: 0.864743	training's binary_logloss: 0.135428	valid_1's auc: 0.832844	valid_1's binary_logloss: 0.143905
# [6]	training's auc: 0.868734	training's binary_logloss: 0.133024	valid_1's auc: 0.832868	valid_1's binary_logloss: 0.14237
# [7]	training's auc: 0.871159	training's binary_logloss: 0.130995	valid_1's auc: 0.83425	valid_1's binary_logloss: 0.141131
# [8]	training's auc: 0.874719	training's binary_logloss: 0.129302	valid_1's auc: 0.835291	valid_1's binary_logloss: 0.140248
# [9]	training's auc: 0.877242	training's binary_logloss: 0.127768	valid_1's auc: 0.835766	valid_1's binary_logloss: 0.139336
# [10]	training's auc: 0.879846	training's binary_logloss: 0.126266	valid_1's auc: 0.836175	valid_1's binary_logloss: 0.138704
# [11]	training's auc: 0.883249	training's binary_logloss: 0.124999	valid_1's auc: 0.836879	valid_1's binary_logloss: 0.13813
# ...
# [36]	training's auc: 0.903252	training's binary_logloss: 0.117263	valid_1's auc: 0.836025	valid_1's binary_logloss: 0.136165
# [37]	training's auc: 0.904211	training's binary_logloss: 0.116819	valid_1's auc: 0.83617	valid_1's binary_logloss: 0.136089
# [38]	training's auc: 0.904932	training's binary_logloss: 0.116429	valid_1's auc: 0.835957	valid_1's binary_logloss: 0.136108
# [39]	training's auc: 0.905786	training's binary_logloss: 0.116025	valid_1's auc: 0.835727	valid_1's binary_logloss: 0.136134
# [40]	training's auc: 0.906905	training's binary_logloss: 0.115669	valid_1's auc: 0.835686	valid_1's binary_logloss: 0.136103
# [41]	training's auc: 0.907852	training's binary_logloss: 0.115287	valid_1's auc: 0.836005	valid_1's binary_logloss: 0.13608
# [42]	training's auc: 0.908881	training's binary_logloss: 0.114953	valid_1's auc: 0.835858	valid_1's binary_logloss: 0.136076
# [43]	training's auc: 0.909783	training's binary_logloss: 0.114569	valid_1's auc: 0.836137	valid_1's binary_logloss: 0.136022
# [44]	training's auc: 0.911239	training's binary_logloss: 0.11418	valid_1's auc: 0.835906	valid_1's binary_logloss: 0.136043
# [45]	training's auc: 0.911987	training's binary_logloss: 0.113827	valid_1's auc: 0.835972	valid_1's binary_logloss: 0.136014
# [46]	training's auc: 0.912805	training's binary_logloss: 0.11346	valid_1's auc: 0.836255	valid_1's binary_logloss: 0.135981
# [47]	training's auc: 0.913817	training's binary_logloss: 0.113116	valid_1's auc: 0.836242	valid_1's binary_logloss: 0.135965
# [48]	training's auc: 0.914674	training's binary_logloss: 0.11275	valid_1's auc: 0.836131	valid_1's binary_logloss: 0.135972
# [49]	training's auc: 0.915773	training's binary_logloss: 0.11238	valid_1's auc: 0.836231	valid_1's binary_logloss: 0.135957
# [50]	training's auc: 0.916501	training's binary_logloss: 0.112056	valid_1's auc: 0.836169	valid_1's binary_logloss: 0.13596
# [51]	training's auc: 0.91754	training's binary_logloss: 0.111729	valid_1's auc: 0.836152	valid_1's binary_logloss: 0.135954
# [52]	training's auc: 0.918582	training's binary_logloss: 0.111418	valid_1's auc: 0.836144	valid_1's binary_logloss: 0.135963
# [53]	training's auc: 0.919257	training's binary_logloss: 0.111105	valid_1's auc: 0.836161	valid_1's binary_logloss: 0.135977
# [54]	training's auc: 0.919942	training's binary_logloss: 0.110817	valid_1's auc: 0.836316	valid_1's binary_logloss: 0.135947
# [55]	training's auc: 0.920917	training's binary_logloss: 0.110475	valid_1's auc: 0.836228	valid_1's binary_logloss: 0.135976
# [56]	training's auc: 0.92169	training's binary_logloss: 0.110105	valid_1's auc: 0.835988	valid_1's binary_logloss: 0.136017
# [57]	training's auc: 0.922293	training's binary_logloss: 0.10978	valid_1's auc: 0.835828	valid_1's binary_logloss: 0.136043
# [58]	training's auc: 0.922976	training's binary_logloss: 0.109457	valid_1's auc: 0.835904	valid_1's binary_logloss: 0.136027
# [59]	training's auc: 0.923342	training's binary_logloss: 0.109195	valid_1's auc: 0.835766	valid_1's binary_logloss: 0.136074
# [60]	training's auc: 0.924074	training's binary_logloss: 0.108896	valid_1's auc: 0.835959	valid_1's binary_logloss: 0.136081
# [61]	training's auc: 0.924806	training's binary_logloss: 0.108543	valid_1's auc: 0.835525	valid_1's binary_logloss: 0.136194
# [62]	training's auc: 0.925383	training's binary_logloss: 0.108257	valid_1's auc: 0.835371	valid_1's binary_logloss: 0.136268
# [63]	training's auc: 0.925859	training's binary_logloss: 0.10797	valid_1's auc: 0.835405	valid_1's binary_logloss: 0.136283
# [64]	training's auc: 0.92635	training's binary_logloss: 0.107696	valid_1's auc: 0.835459	valid_1's binary_logloss: 0.136287
# [65]	training's auc: 0.926752	training's binary_logloss: 0.107447	valid_1's auc: 0.835438	valid_1's binary_logloss: 0.136316
# [66]	training's auc: 0.927184	training's binary_logloss: 0.107194	valid_1's auc: 0.835532	valid_1's binary_logloss: 0.136297
# [67]	training's auc: 0.927765	training's binary_logloss: 0.106984	valid_1's auc: 0.835307	valid_1's binary_logloss: 0.136353
# [68]	training's auc: 0.928143	training's binary_logloss: 0.10677	valid_1's auc: 0.835292	valid_1's binary_logloss: 0.136363
# [69]	training's auc: 0.928721	training's binary_logloss: 0.106486	valid_1's auc: 0.835209	valid_1's binary_logloss: 0.136393
# [70]	training's auc: 0.929233	training's binary_logloss: 0.106213	valid_1's auc: 0.835383	valid_1's binary_logloss: 0.136383
# [71]	training's auc: 0.929741	training's binary_logloss: 0.105931	valid_1's auc: 0.835297	valid_1's binary_logloss: 0.136436
# [72]	training's auc: 0.930229	training's binary_logloss: 0.105679	valid_1's auc: 0.835493	valid_1's binary_logloss: 0.136419
# [73]	training's auc: 0.930627	training's binary_logloss: 0.105464	valid_1's auc: 0.835425	valid_1's binary_logloss: 0.136439
# [74]	training's auc: 0.930946	training's binary_logloss: 0.105248	valid_1's auc: 0.835708	valid_1's binary_logloss: 0.136392
# [75]	training's auc: 0.931377	training's binary_logloss: 0.10505	valid_1's auc: 0.835642	valid_1's binary_logloss: 0.136422
# [76]	training's auc: 0.931701	training's binary_logloss: 0.104832	valid_1's auc: 0.83566	valid_1's binary_logloss: 0.136448
# [77]	training's auc: 0.931983	training's binary_logloss: 0.104638	valid_1's auc: 0.83549	valid_1's binary_logloss: 0.136501
# [78]	training's auc: 0.93227	training's binary_logloss: 0.104422	valid_1's auc: 0.835272	valid_1's binary_logloss: 0.136577
# [79]	training's auc: 0.932651	training's binary_logloss: 0.104166	valid_1's auc: 0.835061	valid_1's binary_logloss: 0.136652
# [80]	training's auc: 0.933069	training's binary_logloss: 0.103911	valid_1's auc: 0.834868	valid_1's binary_logloss: 0.136721
# [81]	training's auc: 0.933376	training's binary_logloss: 0.10371	valid_1's auc: 0.83502	valid_1's binary_logloss: 0.136725
# [82]	training's auc: 0.933639	training's binary_logloss: 0.103527	valid_1's auc: 0.834835	valid_1's binary_logloss: 0.136771
# [83]	training's auc: 0.934204	training's binary_logloss: 0.103261	valid_1's auc: 0.834919	valid_1's binary_logloss: 0.136771
# [84]	training's auc: 0.93443	training's binary_logloss: 0.10306	valid_1's auc: 0.834673	valid_1's binary_logloss: 0.136832
# [1]	training's auc: 0.84019	training's binary_logloss: 0.159097	valid_1's auc: 0.825357	valid_1's binary_logloss: 0.162466
# [2]	training's auc: 0.845215	training's binary_logloss: 0.154279	valid_1's auc: 0.8285	valid_1's binary_logloss: 0.158252
# [3]	training's auc: 0.848041	training's binary_logloss: 0.150574	valid_1's auc: 0.830345	valid_1's binary_logloss: 0.155011
# [4]	training's auc: 0.855084	training's binary_logloss: 0.147451	valid_1's auc: 0.830032	valid_1's binary_logloss: 0.152524
# [5]	training's auc: 0.859552	training's binary_logloss: 0.144809	valid_1's auc: 0.832098	valid_1's binary_logloss: 0.150341
# [6]	training's auc: 0.861983	training's binary_logloss: 0.142511	valid_1's auc: 0.832284	valid_1's binary_logloss: 0.148617
# [7]	training's auc: 0.864403	training's binary_logloss: 0.140499	valid_1's auc: 0.834272	valid_1's binary_logloss: 0.147039
# [8]	training's auc: 0.865781	training's binary_logloss: 0.138755	valid_1's auc: 0.834926	valid_1's binary_logloss: 0.14567
# [9]	training's auc: 0.867471	training's binary_logloss: 0.137226	valid_1's auc: 0.836119	valid_1's binary_logloss: 0.1445
# [10]	training's auc: 0.868473	training's binary_logloss: 0.135862	valid_1's auc: 0.836436	valid_1's binary_logloss: 0.143449
# [11]	training's auc: 0.869793	training's binary_logloss: 0.13458	valid_1's auc: 0.836273	valid_1's binary_logloss: 0.142587
# [12]	training's auc: 0.870537	training's binary_logloss: 0.133381	valid_1's auc: 0.835936	valid_1's binary_logloss: 0.141834
# [13]	training's auc: 0.871753	training's binary_logloss: 0.13228	valid_1's auc: 0.835735	valid_1's binary_logloss: 0.141187
# [14]	training's auc: 0.873822	training's binary_logloss: 0.131304	valid_1's auc: 0.83694	valid_1's binary_logloss: 0.140559
# [15]	training's auc: 0.874897	training's binary_logloss: 0.130401	valid_1's auc: 0.837112	valid_1's binary_logloss: 0.140017
# [16]	training's auc: 0.875879	training's binary_logloss: 0.129538	valid_1's auc: 0.836717	valid_1's binary_logloss: 0.139582
# [17]	training's auc: 0.876966	training's binary_logloss: 0.128761	valid_1's auc: 0.836564	valid_1's binary_logloss: 0.139193
# [18]	training's auc: 0.878165	training's binary_logloss: 0.127995	valid_1's auc: 0.83615	valid_1's binary_logloss: 0.138811
# [19]	training's auc: 0.879151	training's binary_logloss: 0.127247	valid_1's auc: 0.836502	valid_1's binary_logloss: 0.138431
# [20]	training's auc: 0.882114	training's binary_logloss: 0.126525	valid_1's auc: 0.83679	valid_1's binary_logloss: 0.138152
# [21]	training's auc: 0.882811	training's binary_logloss: 0.125887	valid_1's auc: 0.836745	valid_1's binary_logloss: 0.137895
# [22]	training's auc: 0.884078	training's binary_logloss: 0.125241	valid_1's auc: 0.836823	valid_1's binary_logloss: 0.137695
# [23]	training's auc: 0.885122	training's binary_logloss: 0.124645	valid_1's auc: 0.836692	valid_1's binary_logloss: 0.137477
# [24]	training's auc: 0.886345	training's binary_logloss: 0.124059	valid_1's auc: 0.836747	valid_1's binary_logloss: 0.137303
# [25]	training's auc: 0.887642	training's binary_logloss: 0.123496	valid_1's auc: 0.83703	valid_1's binary_logloss: 0.13712
# [26]	training's auc: 0.8889	training's binary_logloss: 0.122963	valid_1's auc: 0.837212	valid_1's binary_logloss: 0.136973
# [27]	training's auc: 0.890164	training's binary_logloss: 0.122428	valid_1's auc: 0.836998	valid_1's binary_logloss: 0.13691
# [28]	training's auc: 0.892012	training's binary_logloss: 0.121849	valid_1's auc: 0.836835	valid_1's binary_logloss: 0.136805
# [29]	training's auc: 0.892973	training's binary_logloss: 0.121377	valid_1's auc: 0.836741	valid_1's binary_logloss: 0.13673
# [30]	training's auc: 0.893878	training's binary_logloss: 0.120877	valid_1's auc: 0.836378	valid_1's binary_logloss: 0.136653
# [31]	training's auc: 0.89516	training's binary_logloss: 0.120374	valid_1's auc: 0.836108	valid_1's binary_logloss: 0.136587
# [32]	training's auc: 0.896143	training's binary_logloss: 0.119907	valid_1's auc: 0.836168	valid_1's binary_logloss: 0.136535
# [33]	training's auc: 0.897077	training's binary_logloss: 0.11945	valid_1's auc: 0.836246	valid_1's binary_logloss: 0.136454
# [34]	training's auc: 0.898366	training's binary_logloss: 0.118985	valid_1's auc: 0.836233	valid_1's binary_logloss: 0.136428
# [35]	training's auc: 0.89939	training's binary_logloss: 0.118566	valid_1's auc: 0.836835	valid_1's binary_logloss: 0.136306
# [36]	training's auc: 0.90016	training's binary_logloss: 0.118157	valid_1's auc: 0.836716	valid_1's binary_logloss: 0.136281
# [37]	training's auc: 0.900989	training's binary_logloss: 0.117782	valid_1's auc: 0.836903	valid_1's binary_logloss: 0.136205
# [38]	training's auc: 0.902037	training's binary_logloss: 0.117357	valid_1's auc: 0.837028	valid_1's binary_logloss: 0.136175
# [39]	training's auc: 0.902816	training's binary_logloss: 0.116973	valid_1's auc: 0.837071	valid_1's binary_logloss: 0.136171
# [40]	training's auc: 0.903661	training's binary_logloss: 0.11657	valid_1's auc: 0.837271	valid_1's binary_logloss: 0.136147
# [41]	training's auc: 0.904503	training's binary_logloss: 0.11619	valid_1's auc: 0.837255	valid_1's binary_logloss: 0.136129
# [42]	training's auc: 0.905461	training's binary_logloss: 0.11582	valid_1's auc: 0.837428	valid_1's binary_logloss: 0.136105
# [43]	training's auc: 0.906349	training's binary_logloss: 0.115461	valid_1's auc: 0.837448	valid_1's binary_logloss: 0.136081
# [44]	training's auc: 0.907445	training's binary_logloss: 0.115114	valid_1's auc: 0.837693	valid_1's binary_logloss: 0.136026
# [45]	training's auc: 0.908137	training's binary_logloss: 0.114774	valid_1's auc: 0.837714	valid_1's binary_logloss: 0.136013
# [46]	training's auc: 0.90894	training's binary_logloss: 0.114428	valid_1's auc: 0.837678	valid_1's binary_logloss: 0.136014
# [47]	training's auc: 0.909855	training's binary_logloss: 0.114057	valid_1's auc: 0.837974	valid_1's binary_logloss: 0.135954
# [48]	training's auc: 0.910646	training's binary_logloss: 0.113727	valid_1's auc: 0.837622	valid_1's binary_logloss: 0.136
# [49]	training's auc: 0.91196	training's binary_logloss: 0.11338	valid_1's auc: 0.837935	valid_1's binary_logloss: 0.135966
# [50]	training's auc: 0.912849	training's binary_logloss: 0.113098	valid_1's auc: 0.837883	valid_1's binary_logloss: 0.135976
# [51]	training's auc: 0.913772	training's binary_logloss: 0.112742	valid_1's auc: 0.837829	valid_1's binary_logloss: 0.136002
# [52]	training's auc: 0.914351	training's binary_logloss: 0.112449	valid_1's auc: 0.837942	valid_1's binary_logloss: 0.135988
# [53]	training's auc: 0.914917	training's binary_logloss: 0.112138	valid_1's auc: 0.83805	valid_1's binary_logloss: 0.135962
# [54]	training's auc: 0.915702	training's binary_logloss: 0.111808	valid_1's auc: 0.837786	valid_1's binary_logloss: 0.136026
# [55]	training's auc: 0.916227	training's binary_logloss: 0.111519	valid_1's auc: 0.837941	valid_1's binary_logloss: 0.13601
# [56]	training's auc: 0.916997	training's binary_logloss: 0.111154	valid_1's auc: 0.837739	valid_1's binary_logloss: 0.136049
# [57]	training's auc: 0.917717	training's binary_logloss: 0.110828	valid_1's auc: 0.837826	valid_1's binary_logloss: 0.136067
# [58]	training's auc: 0.918184	training's binary_logloss: 0.110568	valid_1's auc: 0.837698	valid_1's binary_logloss: 0.136101
# [59]	training's auc: 0.918858	training's binary_logloss: 0.110304	valid_1's auc: 0.83783	valid_1's binary_logloss: 0.136104
# [60]	training's auc: 0.919626	training's binary_logloss: 0.109987	valid_1's auc: 0.837757	valid_1's binary_logloss: 0.136135
# [61]	training's auc: 0.920253	training's binary_logloss: 0.109665	valid_1's auc: 0.837557	valid_1's binary_logloss: 0.136174
# [62]	training's auc: 0.921107	training's binary_logloss: 0.109399	valid_1's auc: 0.838018	valid_1's binary_logloss: 0.136112
# [63]	training's auc: 0.921878	training's binary_logloss: 0.109058	valid_1's auc: 0.837799	valid_1's binary_logloss: 0.136156
# [64]	training's auc: 0.922642	training's binary_logloss: 0.108767	valid_1's auc: 0.837507	valid_1's binary_logloss: 0.13624
# [65]	training's auc: 0.923089	training's binary_logloss: 0.108508	valid_1's auc: 0.837463	valid_1's binary_logloss: 0.136242
# [66]	training's auc: 0.923611	training's binary_logloss: 0.108246	valid_1's auc: 0.837135	valid_1's binary_logloss: 0.136326
# [67]	training's auc: 0.924174	training's binary_logloss: 0.107956	valid_1's auc: 0.836992	valid_1's binary_logloss: 0.136331
# [68]	training's auc: 0.924737	training's binary_logloss: 0.107686	valid_1's auc: 0.836791	valid_1's binary_logloss: 0.136385
# [69]	training's auc: 0.925146	training's binary_logloss: 0.107437	valid_1's auc: 0.836541	valid_1's binary_logloss: 0.136457
# [70]	training's auc: 0.925515	training's binary_logloss: 0.107205	valid_1's auc: 0.836403	valid_1's binary_logloss: 0.136497
# [71]	training's auc: 0.926056	training's binary_logloss: 0.10691	valid_1's auc: 0.836227	valid_1's binary_logloss: 0.136563
# [72]	training's auc: 0.926474	training's binary_logloss: 0.106649	valid_1's auc: 0.836387	valid_1's binary_logloss: 0.136558
# [73]	training's auc: 0.926868	training's binary_logloss: 0.106418	valid_1's auc: 0.836168	valid_1's binary_logloss: 0.136611
# [74]	training's auc: 0.927274	training's binary_logloss: 0.106211	valid_1's auc: 0.836042	valid_1's binary_logloss: 0.136657
# [75]	training's auc: 0.927951	training's binary_logloss: 0.105932	valid_1's auc: 0.835757	valid_1's binary_logloss: 0.13674
# [76]	training's auc: 0.928291	training's binary_logloss: 0.105712	valid_1's auc: 0.83538	valid_1's binary_logloss: 0.136836
# [77]	training's auc: 0.928709	training's binary_logloss: 0.105447	valid_1's auc: 0.835033	valid_1's binary_logloss: 0.136904
# 100%|██████████| 10/10 [03:05<00:00, 18.52s/trial, best loss: -0.8397089766340736]
# best :  {'learning_rate': 0.02347777899863792, 'max_depth': 134.0, 'min_child_samples': 75.0, 'num_leaves': 34.0, 'subsample': 0.7754775757159653}

# %% [markdown]
# best: {'learning_rate': 0.08592271133758617, 'max_depth': 121.0, 'min_child_samples': 69.0, 'num_leaves': 41.0, 'subsample': 0.9148958093027029}

# %%
lgbm_clf =  LGBMClassifier(n_estimators=500, num_leaves=int(41.0),
                           max_depth=int(121.0),
                           min_child_samples=int(69.0),
                           subsample=round(0.9148958093027029, 5),
                           learning_rate=round(0.08592271133758617, 5)
                          )
lgbm_clf.fit(X_tr, y_tr, early_stopping_rounds = 100, eval_metric = "auc", eval_set = [(X_tr, y_tr), (X_val, y_val)])

lgbm_roc_score = roc_auc_score(y_test, lgbm_clf.predict_proba(X_test)[:,1])
print('ROC AUC : {0:.4f}'.format(lgbm_roc_score))
# Out:
# [1]	training's auc: 0.82986	training's binary_logloss: 0.15805	valid_1's auc: 0.815935	valid_1's binary_logloss: 0.159504
# [2]	training's auc: 0.839718	training's binary_logloss: 0.152698	valid_1's auc: 0.822508	valid_1's binary_logloss: 0.154689
# [3]	training's auc: 0.846436	training's binary_logloss: 0.148634	valid_1's auc: 0.829075	valid_1's binary_logloss: 0.151322
# [4]	training's auc: 0.851872	training's binary_logloss: 0.145408	valid_1's auc: 0.832295	valid_1's binary_logloss: 0.148709
# [5]	training's auc: 0.85441	training's binary_logloss: 0.142737	valid_1's auc: 0.835056	valid_1's binary_logloss: 0.146557
# [6]	training's auc: 0.859635	training's binary_logloss: 0.140363	valid_1's auc: 0.836698	valid_1's binary_logloss: 0.144798
# [7]	training's auc: 0.861981	training's binary_logloss: 0.138341	valid_1's auc: 0.838116	valid_1's binary_logloss: 0.143312
# [8]	training's auc: 0.863557	training's binary_logloss: 0.136601	valid_1's auc: 0.838875	valid_1's binary_logloss: 0.142066
# [9]	training's auc: 0.86475	training's binary_logloss: 0.135078	valid_1's auc: 0.839223	valid_1's binary_logloss: 0.141017
# [10]	training's auc: 0.866308	training's binary_logloss: 0.133727	valid_1's auc: 0.839604	valid_1's binary_logloss: 0.140082
# [11]	training's auc: 0.867788	training's binary_logloss: 0.132522	valid_1's auc: 0.839787	valid_1's binary_logloss: 0.139345
# [12]	training's auc: 0.869344	training's binary_logloss: 0.131472	valid_1's auc: 0.839772	valid_1's binary_logloss: 0.13873
# [13]	training's auc: 0.87064	training's binary_logloss: 0.130437	valid_1's auc: 0.840111	valid_1's binary_logloss: 0.138137
# [14]	training's auc: 0.872082	training's binary_logloss: 0.12953	valid_1's auc: 0.840278	valid_1's binary_logloss: 0.137631
# [15]	training's auc: 0.874856	training's binary_logloss: 0.128618	valid_1's auc: 0.840636	valid_1's binary_logloss: 0.137171
# [16]	training's auc: 0.877195	training's binary_logloss: 0.127788	valid_1's auc: 0.840014	valid_1's binary_logloss: 0.136801
# [17]	training's auc: 0.879348	training's binary_logloss: 0.127069	valid_1's auc: 0.839907	valid_1's binary_logloss: 0.136499
# [18]	training's auc: 0.880257	training's binary_logloss: 0.126389	valid_1's auc: 0.840043	valid_1's binary_logloss: 0.136191
# [19]	training's auc: 0.881969	training's binary_logloss: 0.125696	valid_1's auc: 0.839991	valid_1's binary_logloss: 0.135952
# [20]	training's auc: 0.883727	training's binary_logloss: 0.125023	valid_1's auc: 0.840193	valid_1's binary_logloss: 0.13571
# [21]	training's auc: 0.88548	training's binary_logloss: 0.124435	valid_1's auc: 0.840089	valid_1's binary_logloss: 0.135547
# [22]	training's auc: 0.886922	training's binary_logloss: 0.12386	valid_1's auc: 0.840443	valid_1's binary_logloss: 0.135394
# [23]	training's auc: 0.888335	training's binary_logloss: 0.123304	valid_1's auc: 0.840548	valid_1's binary_logloss: 0.135279
# [24]	training's auc: 0.889249	training's binary_logloss: 0.122814	valid_1's auc: 0.840401	valid_1's binary_logloss: 0.135153
# [25]	training's auc: 0.890342	training's binary_logloss: 0.122342	valid_1's auc: 0.840123	valid_1's binary_logloss: 0.135036
# [26]	training's auc: 0.891507	training's binary_logloss: 0.121823	valid_1's auc: 0.839916	valid_1's binary_logloss: 0.134969
# [27]	training's auc: 0.89216	training's binary_logloss: 0.121356	valid_1's auc: 0.839549	valid_1's binary_logloss: 0.134968
# [28]	training's auc: 0.893286	training's binary_logloss: 0.120883	valid_1's auc: 0.839413	valid_1's binary_logloss: 0.134897
# [29]	training's auc: 0.894722	training's binary_logloss: 0.120356	valid_1's auc: 0.839332	valid_1's binary_logloss: 0.134812
# [30]	training's auc: 0.896349	training's binary_logloss: 0.119822	valid_1's auc: 0.840189	valid_1's binary_logloss: 0.134676
# [31]	training's auc: 0.897184	training's binary_logloss: 0.119404	valid_1's auc: 0.84003	valid_1's binary_logloss: 0.134645
# [32]	training's auc: 0.898424	training's binary_logloss: 0.118961	valid_1's auc: 0.840517	valid_1's binary_logloss: 0.13453
# [33]	training's auc: 0.89989	training's binary_logloss: 0.118565	valid_1's auc: 0.840581	valid_1's binary_logloss: 0.134507
# [34]	training's auc: 0.900987	training's binary_logloss: 0.118124	valid_1's auc: 0.840286	valid_1's binary_logloss: 0.134509
# [35]	training's auc: 0.9026	training's binary_logloss: 0.117711	valid_1's auc: 0.84039	valid_1's binary_logloss: 0.134478
# [36]	training's auc: 0.903316	training's binary_logloss: 0.117331	valid_1's auc: 0.840338	valid_1's binary_logloss: 0.134479
# [37]	training's auc: 0.904406	training's binary_logloss: 0.116966	valid_1's auc: 0.840429	valid_1's binary_logloss: 0.134425
# [38]	training's auc: 0.905209	training's binary_logloss: 0.11664	valid_1's auc: 0.840492	valid_1's binary_logloss: 0.134395
# [39]	training's auc: 0.906258	training's binary_logloss: 0.116191	valid_1's auc: 0.840734	valid_1's binary_logloss: 0.134326
# [40]	training's auc: 0.90716	training's binary_logloss: 0.115794	valid_1's auc: 0.840436	valid_1's binary_logloss: 0.13438
# [41]	training's auc: 0.908512	training's binary_logloss: 0.115449	valid_1's auc: 0.840418	valid_1's binary_logloss: 0.134364
# [42]	training's auc: 0.909228	training's binary_logloss: 0.115115	valid_1's auc: 0.840299	valid_1's binary_logloss: 0.134373
# [43]	training's auc: 0.909809	training's binary_logloss: 0.114777	valid_1's auc: 0.840073	valid_1's binary_logloss: 0.134404
# [44]	training's auc: 0.910904	training's binary_logloss: 0.114331	valid_1's auc: 0.839879	valid_1's binary_logloss: 0.134419
# [45]	training's auc: 0.911482	training's binary_logloss: 0.114041	valid_1's auc: 0.839682	valid_1's binary_logloss: 0.134454
# [46]	training's auc: 0.912452	training's binary_logloss: 0.113618	valid_1's auc: 0.839345	valid_1's binary_logloss: 0.134514
# [47]	training's auc: 0.91323	training's binary_logloss: 0.113277	valid_1's auc: 0.839395	valid_1's binary_logloss: 0.134498
# [48]	training's auc: 0.913951	training's binary_logloss: 0.112974	valid_1's auc: 0.83904	valid_1's binary_logloss: 0.134555
# [49]	training's auc: 0.915052	training's binary_logloss: 0.112664	valid_1's auc: 0.839223	valid_1's binary_logloss: 0.134515
# [50]	training's auc: 0.915554	training's binary_logloss: 0.11234	valid_1's auc: 0.839005	valid_1's binary_logloss: 0.134573
# [51]	training's auc: 0.916763	training's binary_logloss: 0.111934	valid_1's auc: 0.838976	valid_1's binary_logloss: 0.134554
# [52]	training's auc: 0.917539	training's binary_logloss: 0.111609	valid_1's auc: 0.838939	valid_1's binary_logloss: 0.134572
# [53]	training's auc: 0.918195	training's binary_logloss: 0.111285	valid_1's auc: 0.838849	valid_1's binary_logloss: 0.134582
# [54]	training's auc: 0.918782	training's binary_logloss: 0.110992	valid_1's auc: 0.83846	valid_1's binary_logloss: 0.13468
# [55]	training's auc: 0.919205	training's binary_logloss: 0.110753	valid_1's auc: 0.838484	valid_1's binary_logloss: 0.13465
# [56]	training's auc: 0.920042	training's binary_logloss: 0.110413	valid_1's auc: 0.838381	valid_1's binary_logloss: 0.134654
# [57]	training's auc: 0.920743	training's binary_logloss: 0.110097	valid_1's auc: 0.838279	valid_1's binary_logloss: 0.134687
# [58]	training's auc: 0.921283	training's binary_logloss: 0.109773	valid_1's auc: 0.837825	valid_1's binary_logloss: 0.134819
# [59]	training's auc: 0.921691	training's binary_logloss: 0.109514	valid_1's auc: 0.837874	valid_1's binary_logloss: 0.13482
# [60]	training's auc: 0.922377	training's binary_logloss: 0.109274	valid_1's auc: 0.837695	valid_1's binary_logloss: 0.134856
# [61]	training's auc: 0.923009	training's binary_logloss: 0.108966	valid_1's auc: 0.837558	valid_1's binary_logloss: 0.134901
# [62]	training's auc: 0.923563	training's binary_logloss: 0.1087	valid_1's auc: 0.837641	valid_1's binary_logloss: 0.134871
# [63]	training's auc: 0.923926	training's binary_logloss: 0.108454	valid_1's auc: 0.837233	valid_1's binary_logloss: 0.134954
# [64]	training's auc: 0.924459	training's binary_logloss: 0.10817	valid_1's auc: 0.837282	valid_1's binary_logloss: 0.134992
# [65]	training's auc: 0.924876	training's binary_logloss: 0.107935	valid_1's auc: 0.837509	valid_1's binary_logloss: 0.13493
# [66]	training's auc: 0.925488	training's binary_logloss: 0.107663	valid_1's auc: 0.837453	valid_1's binary_logloss: 0.134928
# [67]	training's auc: 0.92599	training's binary_logloss: 0.107423	valid_1's auc: 0.836966	valid_1's binary_logloss: 0.135022
# [68]	training's auc: 0.926312	training's binary_logloss: 0.107215	valid_1's auc: 0.836895	valid_1's binary_logloss: 0.135037
# [69]	training's auc: 0.926733	training's binary_logloss: 0.106963	valid_1's auc: 0.836858	valid_1's binary_logloss: 0.135078
# [70]	training's auc: 0.927117	training's binary_logloss: 0.106713	valid_1's auc: 0.836644	valid_1's binary_logloss: 0.135109
# [71]	training's auc: 0.927397	training's binary_logloss: 0.106498	valid_1's auc: 0.836601	valid_1's binary_logloss: 0.135147
# [72]	training's auc: 0.927635	training's binary_logloss: 0.106292	valid_1's auc: 0.836386	valid_1's binary_logloss: 0.135201
# [73]	training's auc: 0.927904	training's binary_logloss: 0.106096	valid_1's auc: 0.836113	valid_1's binary_logloss: 0.135288
# [74]	training's auc: 0.928392	training's binary_logloss: 0.105855	valid_1's auc: 0.835732	valid_1's binary_logloss: 0.135349
# [75]	training's auc: 0.928882	training's binary_logloss: 0.105627	valid_1's auc: 0.835653	valid_1's binary_logloss: 0.135384
# [76]	training's auc: 0.929418	training's binary_logloss: 0.105393	valid_1's auc: 0.835542	valid_1's binary_logloss: 0.135408
# [77]	training's auc: 0.930086	training's binary_logloss: 0.105168	valid_1's auc: 0.835415	valid_1's binary_logloss: 0.135441
# [78]	training's auc: 0.930345	training's binary_logloss: 0.104973	valid_1's auc: 0.835256	valid_1's binary_logloss: 0.13544
# [79]	training's auc: 0.931154	training's binary_logloss: 0.104631	valid_1's auc: 0.835234	valid_1's binary_logloss: 0.135422
# [80]	training's auc: 0.931692	training's binary_logloss: 0.104455	valid_1's auc: 0.835235	valid_1's binary_logloss: 0.135421
# [81]	training's auc: 0.932138	training's binary_logloss: 0.104292	valid_1's auc: 0.835253	valid_1's binary_logloss: 0.135426
# [82]	training's auc: 0.932489	training's binary_logloss: 0.104077	valid_1's auc: 0.83538	valid_1's binary_logloss: 0.135428
# [83]	training's auc: 0.932827	training's binary_logloss: 0.103903	valid_1's auc: 0.835403	valid_1's binary_logloss: 0.135433
# [84]	training's auc: 0.933109	training's binary_logloss: 0.103701	valid_1's auc: 0.83538	valid_1's binary_logloss: 0.135445
# [85]	training's auc: 0.933877	training's binary_logloss: 0.103457	valid_1's auc: 0.835259	valid_1's binary_logloss: 0.135451
# [86]	training's auc: 0.934347	training's binary_logloss: 0.103198	valid_1's auc: 0.835129	valid_1's binary_logloss: 0.135481
# [87]	training's auc: 0.934509	training's binary_logloss: 0.103031	valid_1's auc: 0.834931	valid_1's binary_logloss: 0.135551
# [88]	training's auc: 0.934963	training's binary_logloss: 0.102872	valid_1's auc: 0.834766	valid_1's binary_logloss: 0.1356
# [89]	training's auc: 0.935285	training's binary_logloss: 0.10268	valid_1's auc: 0.834813	valid_1's binary_logloss: 0.135639
# [90]	training's auc: 0.935649	training's binary_logloss: 0.102414	valid_1's auc: 0.83433	valid_1's binary_logloss: 0.135755
# [91]	training's auc: 0.935834	training's binary_logloss: 0.102248	valid_1's auc: 0.834318	valid_1's binary_logloss: 0.135757
# [92]	training's auc: 0.936121	training's binary_logloss: 0.102091	valid_1's auc: 0.834164	valid_1's binary_logloss: 0.135797
# [93]	training's auc: 0.936282	training's binary_logloss: 0.101936	valid_1's auc: 0.834034	valid_1's binary_logloss: 0.135833
# [94]	training's auc: 0.936902	training's binary_logloss: 0.101677	valid_1's auc: 0.833827	valid_1's binary_logloss: 0.13587
# [95]	training's auc: 0.937125	training's binary_logloss: 0.101524	valid_1's auc: 0.833719	valid_1's binary_logloss: 0.135897
# [96]	training's auc: 0.937584	training's binary_logloss: 0.101265	valid_1's auc: 0.833668	valid_1's binary_logloss: 0.135922
# [97]	training's auc: 0.938141	training's binary_logloss: 0.100994	valid_1's auc: 0.833418	valid_1's binary_logloss: 0.135994
# [98]	training's auc: 0.938613	training's binary_logloss: 0.100776	valid_1's auc: 0.833476	valid_1's binary_logloss: 0.136003
# [99]	training's auc: 0.939028	training's binary_logloss: 0.100534	valid_1's auc: 0.83345	valid_1's binary_logloss: 0.136029
# [100]	training's auc: 0.93924	training's binary_logloss: 0.100356	valid_1's auc: 0.83317	valid_1's binary_logloss: 0.136117
# [101]	training's auc: 0.939425	training's binary_logloss: 0.100205	valid_1's auc: 0.832951	valid_1's binary_logloss: 0.136164
# [102]	training's auc: 0.939557	training's binary_logloss: 0.100081	valid_1's auc: 0.832648	valid_1's binary_logloss: 0.136253
# [103]	training's auc: 0.939781	training's binary_logloss: 0.0999107	valid_1's auc: 0.832167	valid_1's binary_logloss: 0.136399
# [104]	training's auc: 0.939975	training's binary_logloss: 0.0997418	valid_1's auc: 0.832088	valid_1's binary_logloss: 0.136458
# [105]	training's auc: 0.940126	training's binary_logloss: 0.0996066	valid_1's auc: 0.831767	valid_1's binary_logloss: 0.13656
# [106]	training's auc: 0.940342	training's binary_logloss: 0.0994205	valid_1's auc: 0.831587	valid_1's binary_logloss: 0.13662
# [107]	training's auc: 0.940501	training's binary_logloss: 0.0992918	valid_1's auc: 0.831622	valid_1's binary_logloss: 0.136638
# [108]	training's auc: 0.940588	training's binary_logloss: 0.0991779	valid_1's auc: 0.831397	valid_1's binary_logloss: 0.136705
# [109]	training's auc: 0.941109	training's binary_logloss: 0.0989409	valid_1's auc: 0.831295	valid_1's binary_logloss: 0.136739
# [110]	training's auc: 0.941431	training's binary_logloss: 0.0988094	valid_1's auc: 0.83114	valid_1's binary_logloss: 0.136806
# [111]	training's auc: 0.941928	training's binary_logloss: 0.0986034	valid_1's auc: 0.831424	valid_1's binary_logloss: 0.136786
# [112]	training's auc: 0.942241	training's binary_logloss: 0.0984628	valid_1's auc: 0.831398	valid_1's binary_logloss: 0.136788
# [113]	training's auc: 0.942561	training's binary_logloss: 0.0983395	valid_1's auc: 0.831411	valid_1's binary_logloss: 0.136811
# [114]	training's auc: 0.942823	training's binary_logloss: 0.0981468	valid_1's auc: 0.831259	valid_1's binary_logloss: 0.13689
# [115]	training's auc: 0.943216	training's binary_logloss: 0.097917	valid_1's auc: 0.831518	valid_1's binary_logloss: 0.136863
# [116]	training's auc: 0.943396	training's binary_logloss: 0.0977663	valid_1's auc: 0.831447	valid_1's binary_logloss: 0.136865
# [117]	training's auc: 0.943546	training's binary_logloss: 0.0976317	valid_1's auc: 0.831259	valid_1's binary_logloss: 0.136918
# [118]	training's auc: 0.943712	training's binary_logloss: 0.0974865	valid_1's auc: 0.831132	valid_1's binary_logloss: 0.136974
# [119]	training's auc: 0.943879	training's binary_logloss: 0.0973293	valid_1's auc: 0.831156	valid_1's binary_logloss: 0.136999
# [120]	training's auc: 0.943997	training's binary_logloss: 0.0971977	valid_1's auc: 0.831235	valid_1's binary_logloss: 0.136974
# [121]	training's auc: 0.944123	training's binary_logloss: 0.0970855	valid_1's auc: 0.831047	valid_1's binary_logloss: 0.137033
# [122]	training's auc: 0.944235	training's binary_logloss: 0.0969682	valid_1's auc: 0.830553	valid_1's binary_logloss: 0.137155
# [123]	training's auc: 0.944351	training's binary_logloss: 0.0968622	valid_1's auc: 0.830428	valid_1's binary_logloss: 0.137194
# [124]	training's auc: 0.944515	training's binary_logloss: 0.0966934	valid_1's auc: 0.830354	valid_1's binary_logloss: 0.137207
# [125]	training's auc: 0.944813	training's binary_logloss: 0.0965792	valid_1's auc: 0.830362	valid_1's binary_logloss: 0.137241
# [126]	training's auc: 0.944952	training's binary_logloss: 0.0964562	valid_1's auc: 0.830206	valid_1's binary_logloss: 0.137295
# [127]	training's auc: 0.94525	training's binary_logloss: 0.0962575	valid_1's auc: 0.830392	valid_1's binary_logloss: 0.137259
# [128]	training's auc: 0.945427	training's binary_logloss: 0.0961212	valid_1's auc: 0.82998	valid_1's binary_logloss: 0.137375
# [129]	training's auc: 0.945633	training's binary_logloss: 0.0959689	valid_1's auc: 0.829615	valid_1's binary_logloss: 0.137477
# [130]	training's auc: 0.94574	training's binary_logloss: 0.0958556	valid_1's auc: 0.829324	valid_1's binary_logloss: 0.137573
# [131]	training's auc: 0.946183	training's binary_logloss: 0.0956307	valid_1's auc: 0.828883	valid_1's binary_logloss: 0.137678
# [132]	training's auc: 0.946396	training's binary_logloss: 0.0954867	valid_1's auc: 0.829034	valid_1's binary_logloss: 0.137685
# [133]	training's auc: 0.946634	training's binary_logloss: 0.0952924	valid_1's auc: 0.828794	valid_1's binary_logloss: 0.137747
# [134]	training's auc: 0.947022	training's binary_logloss: 0.0950834	valid_1's auc: 0.828896	valid_1's binary_logloss: 0.137759
# [135]	training's auc: 0.947216	training's binary_logloss: 0.0949346	valid_1's auc: 0.828721	valid_1's binary_logloss: 0.137833
# [136]	training's auc: 0.947872	training's binary_logloss: 0.0946482	valid_1's auc: 0.82858	valid_1's binary_logloss: 0.137889
# [137]	training's auc: 0.948207	training's binary_logloss: 0.094475	valid_1's auc: 0.828652	valid_1's binary_logloss: 0.137903
# [138]	training's auc: 0.94851	training's binary_logloss: 0.0942655	valid_1's auc: 0.828615	valid_1's binary_logloss: 0.137944
# [139]	training's auc: 0.948591	training's binary_logloss: 0.0941801	valid_1's auc: 0.828118	valid_1's binary_logloss: 0.138048
# ROC AUC : 0.8228
